# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Final-Project-Submission-Capstone-Project" data-toc-modified-id="Final-Project-Submission-Capstone-Project-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Final Project Submission Capstone Project</a></span><ul class="toc-item"><li><span><a href="#Summary:" data-toc-modified-id="Summary:-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Summary:</a></span></li></ul></li><li><span><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Import Libraries</a></span></li><li><span><a href="#Choose-Zip-Codes-by-Percent-Increase-in-Median-Price" data-toc-modified-id="Choose-Zip-Codes-by-Percent-Increase-in-Median-Price-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Choose Zip Codes by Percent Increase in Median Price</a></span><ul class="toc-item"><li><span><a href="#Create-Melted-Dataframe-of-ZipCodes" data-toc-modified-id="Create-Melted-Dataframe-of-ZipCodes-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Create Melted Dataframe of ZipCodes</a></span></li></ul></li><li><span><a href="#Data-Exploration" data-toc-modified-id="Data-Exploration-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Data Exploration</a></span><ul class="toc-item"><li><span><a href="#Correlation-Heat-Map" data-toc-modified-id="Correlation-Heat-Map-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Correlation Heat Map</a></span><ul class="toc-item"><li><span><a href="#Remove-Irrelevant-Columns" data-toc-modified-id="Remove-Irrelevant-Columns-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Remove Irrelevant Columns</a></span></li></ul></li><li><span><a href="#.describe()" data-toc-modified-id=".describe()-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>.describe()</a></span></li><li><span><a href="#Plot-Target-Values" data-toc-modified-id="Plot-Target-Values-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Plot Target Values</a></span></li><li><span><a href="#Check-for-Stationarity" data-toc-modified-id="Check-for-Stationarity-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Check for Stationarity</a></span></li><li><span><a href="#Calculate-p,d,q" data-toc-modified-id="Calculate-p,d,q-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Calculate p,d,q</a></span><ul class="toc-item"><li><span><a href="#Calculate-p-for-SARIMA" data-toc-modified-id="Calculate-p-for-SARIMA-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Calculate p for SARIMA</a></span><ul class="toc-item"><li><span><a href="#Best-value-for-p" data-toc-modified-id="Best-value-for-p-4.5.1.1"><span class="toc-item-num">4.5.1.1&nbsp;&nbsp;</span>Best value for p</a></span></li></ul></li><li><span><a href="#Best-value-for-q" data-toc-modified-id="Best-value-for-q-4.5.2"><span class="toc-item-num">4.5.2&nbsp;&nbsp;</span>Best value for q</a></span><ul class="toc-item"><li><span><a href="#Best-value-for-q" data-toc-modified-id="Best-value-for-q-4.5.2.1"><span class="toc-item-num">4.5.2.1&nbsp;&nbsp;</span>Best value for q</a></span></li></ul></li><li><span><a href="#Manual-SARIMA---calculate-rmse" data-toc-modified-id="Manual-SARIMA---calculate-rmse-4.5.3"><span class="toc-item-num">4.5.3&nbsp;&nbsp;</span>Manual SARIMA - calculate rmse</a></span></li></ul></li><li><span><a href="#Decomposition---Analyze-Trend-and-Seasonality" data-toc-modified-id="Decomposition---Analyze-Trend-and-Seasonality-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Decomposition - Analyze Trend and Seasonality</a></span><ul class="toc-item"><li><span><a href="#Pattern-detected" data-toc-modified-id="Pattern-detected-4.6.1"><span class="toc-item-num">4.6.1&nbsp;&nbsp;</span>Pattern detected</a></span></li></ul></li></ul></li><li><span><a href="#Model-First-Stock" data-toc-modified-id="Model-First-Stock-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Model First Stock</a></span><ul class="toc-item"><li><span><a href="#SARIMA-Model" data-toc-modified-id="SARIMA-Model-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>SARIMA Model</a></span><ul class="toc-item"><li><span><a href="#GridSearch-optimal-parameters,-Model,-Predict,-calculate-RMSE" data-toc-modified-id="GridSearch-optimal-parameters,-Model,-Predict,-calculate-RMSE-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>GridSearch optimal parameters, Model, Predict, calculate RMSE</a></span></li></ul></li><li><span><a href="#ARIMA-model---if-there-isn't-seasonality" data-toc-modified-id="ARIMA-model---if-there-isn't-seasonality-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>ARIMA model - if there isn't seasonality</a></span><ul class="toc-item"><li><span><a href="#Grid-Search-ARIMA-Parameters" data-toc-modified-id="Grid-Search-ARIMA-Parameters-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Grid Search ARIMA Parameters</a></span></li><li><span><a href="#ARIMA-Model-without-Z-Score-Standardization,-Calculate-RMSE" data-toc-modified-id="ARIMA-Model-without-Z-Score-Standardization,-Calculate-RMSE-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>ARIMA Model without Z-Score Standardization, Calculate RMSE</a></span></li><li><span><a href="#Z-Score-Standardization" data-toc-modified-id="Z-Score-Standardization-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Z-Score Standardization</a></span></li></ul></li><li><span><a href="#ARIMA-with-Z-Score-Standardization,-RMSE-Calculated" data-toc-modified-id="ARIMA-with-Z-Score-Standardization,-RMSE-Calculated-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>ARIMA with Z-Score Standardization, RMSE Calculated</a></span><ul class="toc-item"><li><span><a href="#Log-Normalize-Values,-drop-Nan" data-toc-modified-id="Log-Normalize-Values,-drop-Nan-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Log Normalize Values, drop Nan</a></span></li><li><span><a href="#Summary:" data-toc-modified-id="Summary:-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Summary:</a></span></li></ul></li></ul></li><li><span><a href="#Multiple-Linear-Regression" data-toc-modified-id="Multiple-Linear-Regression-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Multiple Linear Regression</a></span></li></ul></div>

# %% [markdown]
# # Final Project Submission Capstone Project
# * Student name: Jim Petoskey
# * Student pace: Self-paced
# * Scheduled project review date/time: ________
# * Instructor name: Abhineet Kulkarni
# * [Blog post URL: Time Series Decomposition - Spotting Seasonality](______)
# * [Time Series Zillow Starter Repository](_____)

# %% [markdown]
# ## Summary:
# * Top Zip Codes to Invest in:
#     * Oakland, CA 94606
#         * High Return (68.1%), Low Risk
#     * Lake Worth, FL 33460
#         * Highest Return (93%), Modest Risk
#     * Boise, ID 83703
#         * Moderately high return (55.1%), Low Risk
# ***
# * Process:
#
#     1. Measure rate of return for every zip code in US from April 2012 to April 2018
#     2. Choose top 15 zip codes by rate of return
#     3. Added top Mountain Towns and Mid-size Cities from Adding Breadth of Zip Codes Section
#     4. Model price predictions, measure accuracy with RMSE
#     5. Choose zip codes which are modeled most accurately
#     6. Re-model those zip codes, forecast rate of return, plot predictions and confidence interval
#     7. Propose investment in zip codes with lower risk, as measured by the confidence interval and RMSE, and high predicted returns over 5 year investment timeline

# %% [markdown]
# # Import Libraries

# %%
# Import necessary libraries
import warnings
warnings.filterwarnings('ignore')
import itertools
import pandas as pd
import numpy as np
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
plt.style.use('default')
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.ticker as mtick

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Choose Zip Codes by Percent Increase in Median Price
# * Time Period: April 2012 to April 2018

# %% [markdown]
# ## Create Melted Dataframe of ZipCodes

# %%
# Create dataframe from zillow median home price data
df = pd.read_csv(r'/Users/jimpetoskey/Documents/Flatiron/phase5/data/stock_prices.csv')

# %%
# make copy of df
df1 = df.copy()

df1
# Out:
#                  RowId        Date  SecuritiesCode    Open    High     Low  \
# 0        20170104_1301  2017-01-04            1301  2734.0  2755.0  2730.0
# 1        20170104_1332  2017-01-04            1332   568.0   576.0   563.0
# 2        20170104_1333  2017-01-04            1333  3150.0  3210.0  3140.0
# 3        20170104_1376  2017-01-04            1376  1510.0  1550.0  1510.0
# 4        20170104_1377  2017-01-04            1377  3270.0  3350.0  3270.0
# ...                ...         ...             ...     ...     ...     ...
# 2332526  20211203_9990  2021-12-03            9990   514.0   528.0   513.0
# 2332527  20211203_9991  2021-12-03            9991   782.0   794.0   782.0
# 2332528  20211203_9993  2021-12-03            9993  1690.0  1690.0  1645.0
# 2332529  20211203_9994  2021-12-03            9994  2388.0  2396.0  2380.0
# 2332530  20211203_9997  2021-12-03            9997   690.0   711.0   686.0
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2332531 entries, 0 to 2332530
# Data columns (total 12 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   RowId             object
#  1   Date              object
#  2   SecuritiesCode    int64
#  3   Open              float64
#  4   High              float64
#  5   Low               float64
#  6   Close             float64
#  7   Volume            int64
#  8   AdjustmentFactor  float64
#  9   ExpectedDividend  float64
#  10  SupervisionFlag   bool
#  11  Target            float64
# dtypes: bool(1), float64(7), int64(2), object(2)
# memory usage: 198.0+ MB

# %%
# Convert RowId to string to select for substring of stock id
df1['RowId'] = df['RowId'].astype('|S')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2332531 entries, 0 to 2332530
# Data columns (total 12 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   RowId             |S13
#  1   Date              object
#  2   SecuritiesCode    int64
#  3   Open              float64
#  4   High              float64
#  5   Low               float64
#  6   Close             float64
#  7   Volume            int64
#  8   AdjustmentFactor  float64
#  9   ExpectedDividend  float64
#  10  SupervisionFlag   bool
#  11  Target            float64
# dtypes: bool(1), bytes104(1), float64(7), int64(2), object(1)
# memory usage: 209.1+ MB

# %%
# Pull one stock's values for given stock from stock_prices
values1301 = df1.loc[df1['RowId'].str.contains("1301", case=False)]
values1301
# Out:
#                     RowId        Date  SecuritiesCode    Open    High     Low  \
# 0        b'20170104_1301'  2017-01-04            1301  2734.0  2755.0  2730.0
# 1865     b'20170105_1301'  2017-01-05            1301  2743.0  2747.0  2735.0
# 3730     b'20170106_1301'  2017-01-06            1301  2734.0  2744.0  2720.0
# 5595     b'20170110_1301'  2017-01-10            1301  2745.0  2754.0  2735.0
# 7460     b'20170111_1301'  2017-01-11            1301  2748.0  2752.0  2737.0
# ...                   ...         ...             ...     ...     ...     ...
# 2322531  b'20211129_1301'  2021-11-29            1301  2975.0  2984.0  2951.0
# 2324531  b'20211130_1301'  2021-11-30            1301  2953.0  2997.0  2900.0
# 2326531  b'20211201_1301'  2021-12-01            1301  2909.0  2936.0  2909.0
# 2328531  b'20211202_1301'  2021-12-02            1301  2949.0  2973.0  2933.0
# 2330531  b'20211203_1301'  2021-12-03            1301  2983.0  2983.0  2965.0
#
# ...

# %%
# Convert Date to DateTime
values1301['Date'] = pd.to_datetime(values1301['Date'], infer_datetime_format=True)
values1301.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1202 entries, 0 to 2330531
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   RowId             1202 non-null   |S13
#  1   Date              1202 non-null   datetime64[ns]
#  2   SecuritiesCode    1202 non-null   int64
#  3   Open              1201 non-null   float64
#  4   High              1201 non-null   float64
#  5   Low               1201 non-null   float64
#  6   Close             1201 non-null   float64
#  7   Volume            1202 non-null   int64
#  8   AdjustmentFactor  1202 non-null   float64
#  9   ExpectedDividend  5 non-null      float64
#  10  SupervisionFlag   1202 non-null   bool
#  11  Target            1202 non-null   float64
# dtypes: bool(1), bytes104(1), datetime64[ns](1), float64(7), int64(2)
# memory usage: 119.7 KB

# %%
# create new df with datetime index and Target row only
#df_ind = df.set_index(['A', 'B'])
values1301_copy = values1301.copy()
values1301_copy = values1301_copy.iloc[:, [1,11]]
values1301_copy = values1301_copy.set_index(['Date'])
values1301_copy
# Out:
#               Target
# Date
# 2017-01-04  0.000730
# 2017-01-05  0.002920
# 2017-01-06 -0.001092
# 2017-01-10 -0.005100
# 2017-01-11 -0.003295
# ...              ...
# 2021-11-29  0.003793
# 2021-11-30  0.007558
# 2021-12-01  0.016706
# 2021-12-02 -0.003689
# 2021-12-03  0.031639
#
# [1202 rows x 1 columns]

# %% [markdown]
# # Data Exploration

# %%
# Check for missing data
print(values1301_copy['Target'].isnull().sum().sum())
# Out:
# 0

# %% [markdown]
# ## Correlation Heat Map

# %% [markdown]
# ### Remove Irrelevant Columns
# * SupervisionFlag - Bool with only 1 value
# * RowId - all from the same Id value
# * AdjustmentFactor - same value for all rows

# %%
heat_map = values1301.copy()

# %%
heat_map = heat_map.drop(['SupervisionFlag','RowId','AdjustmentFactor'], axis=1)

# %%
# Create a df with the target as the first column,
# then compute the correlation matrix
heatmap_data = heat_map
corr = heatmap_data.corr()

# Set up figure and axes
fig, ax = plt.subplots(figsize=(5, 8))

# Plot a heatmap of the correlation matrix, with both
# numbers and colors indicating the correlations
sns.heatmap(
    # Specifies the data to be plotted
    data=corr,
    # The mask means we only show half the values,
    # instead of showing duplicates. It's optional.
    mask=np.triu(np.ones_like(corr, dtype=bool)),
    # Specifies that we should use the existing axes
    ax=ax,
    # Specifies that we want labels, not just colors
    annot=True,
    # Customizes colorbar appearance
    cbar_kws={"label": "Correlation", "orientation": "horizontal", "pad": .2, "extend": "both"}
)

# Customize the plot appearance
ax.set_title("Heatmap of Correlation Between Attributes (Including Target)");

# %% [markdown]
# ## .describe()

# %%
values1301_copy.describe()
# Out:
#             Target
# count  1202.000000
# mean      0.000176
# std       0.012862
# min      -0.064186
# 25%      -0.006397
# 50%       0.000000
# 75%       0.006439
# max       0.069686

# %% [markdown]
# ## Plot Target Values

# %%
plt.figure(figsize=(12,8))
plt.subplot(411)
plt.title(str(1301))
plt.plot(values1301_copy, label='Original', color='blue')
plt.legend(loc='best')

# %% [markdown]
# ## Check for Stationarity

# %%
from statsmodels.tsa.stattools import adfuller
import numpy as np
def check_stationarity(ts):
    dftest = adfuller(ts)
    adf = dftest[0]
    pvalue = dftest[1]
    critical_value = dftest[4]['5%']
    if (pvalue < 0.05) and (adf < critical_value):
        print('The series is stationary')
    else:
        print('The series is NOT stationary')

# %%
check_stationarity(values1301_copy)
# Out:
# The series is stationary

# %% [markdown]
# ## Calculate p,d,q
# * d = 0 because there is no differencing needed to make model stationary
# * p =
# * q =

# %% [markdown]
# ### Calculate p for SARIMA
# * Plot PACF

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_pacf(values1301_copy, lags =12)
plt.show()

# %% [markdown]
# #### Best value for p
# * 2 or 4 are probably the best values because they are almost outside the confidence interval

# %% [markdown]
# ### Best value for q
# * Plot ACF

# %%
plot_acf(values1301_copy, lags =12)
plt.show()

# %% [markdown]
# #### Best value for q
# * Again, 2 and 4 are probably the best values, or 0

# %% [markdown]
# ### Manual SARIMA - calculate rmse

# %%
train = values1301_copy
train
# Out:
#               Target
# Date
# 2017-01-04  0.000730
# 2017-01-05  0.002920
# 2017-01-06 -0.001092
# 2017-01-10 -0.005100
# 2017-01-11 -0.003295
# ...              ...
# 2021-11-29  0.003793
# 2021-11-30  0.007558
# 2021-12-01  0.016706
# 2021-12-02 -0.003689
# 2021-12-03  0.031639
#
# [1202 rows x 1 columns]

# %%
train = values1301_copy.iloc[:1080]
test = values1301_copy.iloc[1080:]
p = 2
d = 0
q = 2

from statsmodels.tsa.statespace.sarimax import SARIMAX
model = SARIMAX(train, order=(p,d,q))
model_fit = model.fit()

# %%
train
# Out:
#               Target
# Date
# 2017-01-04  0.000730
# 2017-01-05  0.002920
# 2017-01-06 -0.001092
# 2017-01-10 -0.005100
# 2017-01-11 -0.003295
# ...              ...
# 2021-06-01  0.006169
# 2021-06-02 -0.000341
# 2021-06-03  0.002385
# 2021-06-04 -0.006118
# 2021-06-07  0.008892
#
# [1080 rows x 1 columns]

# %%
n_test = test.shape[0]
n_test
# Out:
# 122

# %%
n_test = test.shape[0]
ts_pred = model_fit.forecast(steps=n_test)

# %%
ts_pred
# Out:
# 1080    1.409047e-03
# 1081   -4.881501e-04
# 1082   -8.987335e-04
# 1083    5.142315e-04
# 1084    5.346967e-04
#             ...
# 1197   -1.460338e-12
# 1198   -6.350411e-13
# 1199    1.148213e-12
# 1200    2.287034e-13
# 1201   -8.513885e-13
# Name: predicted_mean, Length: 122, dtype: float64

# %%
plt.plot(ts_pred, label='prediction')
plt.plot(test, label='actual')
plt.title('Multi-step Forecasting (manual parameters)')
plt.legend()
plt.grid()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Decomposition - Analyze Trend and Seasonality

# %%
#Apply seasonal_decompose()
decomposition = seasonal_decompose(values1301_copy, model='additive', period=360)

# Gather the trend, seasonality, and residuals 
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid
    
# Plot gathered statistics
plt.figure(figsize=(16,12))
plt.subplot(511)
plt.title(str(1301))
plt.plot(values1301_copy, label='Original', color='blue')
plt.legend(loc='best')
plt.subplot(512)
plt.plot(trend, label='Trend', color='blue')
plt.legend(loc='best')
plt.subplot(513)
plt.plot(seasonal,label='Seasonality', color='blue')
plt.legend(loc='best')
# inspect seasonality on shorter period of time - is there a pattern?
seasonal_snipet = seasonal.iloc[1022:]
plt.subplot(514)
plt.plot(seasonal_snipet,label='Seasonality_Snippet', color='blue')
plt.legend(loc='best')
plt.subplot(515)
plt.plot(residual, label='Residuals', color='blue')
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# ### Pattern detected
# * The pattern comes from the period that is set in the seasonal_decompose function and is equal to that period.

# %%
seasonal_snipet = seasonal.iloc[1150:]
#seasonal_snipet

# %% [markdown]
# # Model First Stock

# %% [markdown]
# ## SARIMA Model
# * For Top Prospective Zip Codes

# %%
# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
pdqs = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %% [markdown]
# ### GridSearch optimal parameters, Model, Predict, calculate RMSE
# * Run for all zip codes in prospects

# %%
train = values1301_copy.iloc[:1080]
test = values1301_copy.iloc[1080:]
test
# Out:
#               Target
# Date
# 2021-06-08 -0.001017
# 2021-06-09 -0.007805
# 2021-06-10  0.002394
# 2021-06-11  0.006141
# 2021-06-14 -0.003052
# ...              ...
# 2021-11-29  0.003793
# 2021-11-30  0.007558
# 2021-12-01  0.016706
# 2021-12-02 -0.003689
# 2021-12-03  0.031639
#
# [122 rows x 1 columns]

# %%
arima = (0,0,0)
s = (0,0,0,12)

ARIMA_MODEL = sm.tsa.statespace.SARIMAX(train, 
                                            order=arima, 
                                            seasonal_order=s, 
                                            enforce_stationarity=False, 
                                            enforce_invertibility=False)

# Fit the model and print results
output = ARIMA_MODEL.fit()

print(output.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.0002   4.58e-06     37.130      0.000       0.000       0.000
# ...

# %%
# Call plot_diagnostics() on the results calculated above 
output.plot_diagnostics(figsize=(15, 18))
plt.show()

# %%
# Get predictions and forecast in dataframe
prediction = output.forecast(steps=122)
prediction
# Out:
# 1080    0.0
# 1081    0.0
# 1082    0.0
# 1083    0.0
# 1084    0.0
#        ...
# 1197    0.0
# 1198    0.0
# 1199    0.0
# 1200    0.0
# 1201    0.0
# Name: predicted_mean, Length: 122, dtype: float64

# %% [markdown]
# ## ARIMA model - if there isn't seasonality

# %% [markdown]
# ### Grid Search ARIMA Parameters

# %%
# grid search ARIMA parameters for time series
import warnings
from math import sqrt
from pandas import read_csv
from pandas import datetime
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
 
# evaluate an ARIMA model for a given order (p,d,q)
def evaluate_arima_model(X, arima_order):
	# prepare training dataset
	train_size = int(len(X) * 0.66)
	train, test = X[0:train_size], X[train_size:]
	history = [x for x in train]
	# make predictions
	predictions = list()
	for t in range(len(test)):
		model = ARIMA(history, order=arima_order)
		model_fit = model.fit()
		yhat = model_fit.forecast()[0]
		predictions.append(yhat)
		history.append(test[t])
	# calculate out of sample error
	rmse = sqrt(mean_squared_error(test, predictions))
	return rmse
 
# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
	dataset = dataset.astype('float32')
	best_score, best_cfg = float("inf"), None
	for p in p_values:
		for d in d_values:
			for q in q_values:
				order = (p,d,q)
				try:
					rmse = evaluate_arima_model(dataset, order)
					if rmse < best_score:
						best_score, best_cfg = rmse, order
					print('ARIMA%s RMSE=%.3f' % (order,rmse))
				except:
					continue
	print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))
 
# load dataset
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
series = values1301_copy
# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(series.values, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) RMSE=0.011
# ARIMA(0, 0, 1) RMSE=0.011

# %% [markdown]
# ### ARIMA Model without Z-Score Standardization, Calculate RMSE

# %%
# evaluate an ARIMA model using a walk-forward validation
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt
# load dataset
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
series = values1301_copy
#series.index = series.index.to_period('M')
# split into train and test sets
X = series.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
# walk-forward validation
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,1))
	model_fit = model.fit()
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	#print('predicted=%f, expected=%f' % (yhat, obs))
# evaluate forecasts
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# plot forecasts against actual outcomes
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# Test RMSE: 0.011

# %% [markdown]
# ### Z-Score Standardization

# %%
import scipy.stats as stats
values = values1301_copy['Target']

zscores = stats.zscore(values)
print(zscores)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-67d00415d154> in <module>
#       1 import scipy.stats as stats
# ----> 2 values = values1301_copy['Target']
#       3
#       4 zscores = stats.zscore(values)
#       5 print(zscores)
#
# NameError: name 'values1301_copy' is not defined

# %%
values1301_zscore = values1301_copy.copy()
values1301_zscore['Z_Scores'] = zscores
values1301_zscore = values1301_zscore.drop('Target', axis=1)
values1301_zscore

# %%
values1301_zscore.describe()
# Out:
#            Z_Scores
# count  1.202000e+03
# mean   1.330051e-17
# std    1.000416e+00
# min   -5.006322e+00
# 25%   -5.113371e-01
# 50%   -1.372644e-02
# 75%    4.870882e-01
# max    5.406673e+00

# %% [markdown]
# ## ARIMA with Z-Score Standardization, RMSE Calculated

# %%
# evaluate an ARIMA model using a walk-forward validation
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt
# load dataset
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
series = values1301_zscore
#series.index = series.index.to_period('M')
# split into train and test sets
X = series.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
# walk-forward validation
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,0))
	model_fit = model.fit()
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	#print('predicted=%f, expected=%f' % (yhat, obs))
# evaluate forecasts
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# plot forecasts against actual outcomes
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# Test RMSE: 0.953

# %% [markdown]
# ### Log Normalize Values, drop Nan

# %%
values1301_log = values1301_copy.copy()
log_norm_1301 = np.log(values1301_log)
# Replace missing and -inf values from residuals with 0
log_norm_1301['Target'] = log_norm_1301['Target'].fillna(0)
log_norm_1301['Target'] = log_norm_1301['Target'].replace([np.inf, -np.inf], 0)  
# Check for missing data
print(log_norm_1301['Target'].isnull().sum().sum())
log_norm_1301.value_counts()
# Out:
# 0
# Target
#  0.000000    614
# -6.403574      4
# -5.318120      3
# -5.594711      2
# -6.620073      2
#             ...
# -4.496630      1
# -4.493493      1
# -4.493440      1
# -4.488636      1
# -7.996317      1
# Length: 559, dtype: int64

# %%
# evaluate an ARIMA model using a walk-forward validation
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt
# load dataset
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
series = log_norm_1301
series.index = series.index.to_period('M')
# split into train and test sets
X = series.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
# walk-forward validation
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,0))
	model_fit = model.fit()
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	#print('predicted=%f, expected=%f' % (yhat, obs))
# evaluate forecasts
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# plot forecasts against actual outcomes
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# Test RMSE: 2.937

# %% [markdown]
# ### Summary:
# * Z-Score Standardization of raw values (Sharpe Ratio's) caused a similar magnitude of error in model as the RMSE for the raw data set was 0.012 and the RMSE for the Z-Score Standardized data set was 0.953.
#     * Considering the raw data set has a standard deviation of .128, the Z-Score standardized RMSE value of 0.953 is very close to 1 standard deviation, so they have a similar level of error.

# %% [markdown]
# # Multiple Linear Regression

# %%
# Make new df for lin reg
values1301_linreg = values1301.copy()

# set index to date
values1301_linreg = values1301_linreg.set_index(['Date'])

values1301_linreg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1202 entries, 2017-01-04 to 2021-12-03
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   RowId             1202 non-null   |S13
#  1   SecuritiesCode    1202 non-null   int64
#  2   Open              1201 non-null   float64
#  3   High              1201 non-null   float64
#  4   Low               1201 non-null   float64
#  5   Close             1201 non-null   float64
#  6   Volume            1202 non-null   int64
#  7   AdjustmentFactor  1202 non-null   float64
#  8   ExpectedDividend  5 non-null      float64
#  9   SupervisionFlag   1202 non-null   bool
#  10  Target            1202 non-null   float64
# dtypes: bool(1), bytes104(1), float64(7), int64(2)
# memory usage: 110.3 KB

# %%
values1301_linreg.describe()
# Out:
#        SecuritiesCode         Open         High          Low        Close  \
# count          1202.0  1201.000000  1201.000000  1201.000000  1201.000000
# mean           1301.0  3082.315570  3105.367194  3057.169858  3082.057452
# std               0.0   382.866099   387.438979   379.047439   383.373850
# min            1301.0  2255.000000  2326.000000  2202.000000  2289.000000
# 25%            1301.0  2825.000000  2847.000000  2805.000000  2825.000000
# 50%            1301.0  2992.000000  3015.000000  2975.000000  2993.000000
# 75%            1301.0  3185.000000  3215.000000  3165.000000  3195.000000
# max            1301.0  4430.000000  4460.000000  4340.000000  4430.000000
#
#               Volume  AdjustmentFactor  ExpectedDividend       Target
# count    1202.000000            1202.0          5.000000  1202.000000
# mean    27271.630616               1.0         64.000000     0.000176
# std     20897.365917               0.0          5.477226     0.012862
# ...

# %%
values1301_linreg['SupervisionFlag'].describe()
# Out:
# count      1202
# unique        1
# top       False
# freq       1202
# Name: SupervisionFlag, dtype: object

# %%
# drop SupervisionFlag, AdjustmentFactor, SecuritiesCode
