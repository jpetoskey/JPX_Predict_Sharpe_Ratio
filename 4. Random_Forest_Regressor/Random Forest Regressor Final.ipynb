# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import Libraries</a></span></li><li><span><a href="#Preprocessing" data-toc-modified-id="Preprocessing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Create-data-frames" data-toc-modified-id="Create-data-frames-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Create data frames</a></span></li><li><span><a href="#Create-Train-and-Test-df's" data-toc-modified-id="Create-Train-and-Test-df's-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Create Train and Test df's</a></span></li><li><span><a href="#Modify-sample_prediction-for-testing" data-toc-modified-id="Modify-sample_prediction-for-testing-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Modify sample_prediction for testing</a></span></li><li><span><a href="#Identify-Single-Stock" data-toc-modified-id="Identify-Single-Stock-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Identify Single Stock</a></span><ul class="toc-item"><li><span><a href="#Practice-with-features" data-toc-modified-id="Practice-with-features-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Practice with features</a></span></li></ul></li><li><span><a href="#Explore-Columns" data-toc-modified-id="Explore-Columns-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Explore Columns</a></span><ul class="toc-item"><li><span><a href="#How-many-null-values-in-each-column?" data-toc-modified-id="How-many-null-values-in-each-column?-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>How many null values in each column?</a></span><ul class="toc-item"><li><span><a href="#Forward-Fill" data-toc-modified-id="Forward-Fill-2.5.1.1"><span class="toc-item-num">2.5.1.1&nbsp;&nbsp;</span>Forward Fill</a></span></li></ul></li><li><span><a href="#Describe-sparse-and-singular-value-columns" data-toc-modified-id="Describe-sparse-and-singular-value-columns-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Describe sparse and singular value columns</a></span></li></ul></li><li><span><a href="#Plot-Attributes" data-toc-modified-id="Plot-Attributes-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Plot Attributes</a></span><ul class="toc-item"><li><span><a href="#Plot-Daily-Close" data-toc-modified-id="Plot-Daily-Close-2.6.1"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span>Plot Daily Close</a></span></li><li><span><a href="#Plot-Daily-Spread" data-toc-modified-id="Plot-Daily-Spread-2.6.2"><span class="toc-item-num">2.6.2&nbsp;&nbsp;</span>Plot Daily Spread</a></span></li><li><span><a href="#Plot-Close-Difference" data-toc-modified-id="Plot-Close-Difference-2.6.3"><span class="toc-item-num">2.6.3&nbsp;&nbsp;</span>Plot Close Difference</a></span></li></ul></li><li><span><a href="#Add-Financials" data-toc-modified-id="Add-Financials-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Add Financials</a></span><ul class="toc-item"><li><span><a href="#Merge-Function" data-toc-modified-id="Merge-Function-2.7.1"><span class="toc-item-num">2.7.1&nbsp;&nbsp;</span>Merge Function</a></span></li><li><span><a href="#Explore-Financials" data-toc-modified-id="Explore-Financials-2.7.2"><span class="toc-item-num">2.7.2&nbsp;&nbsp;</span>Explore Financials</a></span></li><li><span><a href="#Long-copy-of-merge" data-toc-modified-id="Long-copy-of-merge-2.7.3"><span class="toc-item-num">2.7.3&nbsp;&nbsp;</span>Long copy of merge</a></span></li></ul></li><li><span><a href="#Add-Stock-List" data-toc-modified-id="Add-Stock-List-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Add Stock List</a></span><ul class="toc-item"><li><span><a href="#Merge-Function" data-toc-modified-id="Merge-Function-2.8.1"><span class="toc-item-num">2.8.1&nbsp;&nbsp;</span>Merge Function</a></span></li><li><span><a href="#Explore-Stock-List" data-toc-modified-id="Explore-Stock-List-2.8.2"><span class="toc-item-num">2.8.2&nbsp;&nbsp;</span>Explore Stock List</a></span></li><li><span><a href="#Practice-Merge-Code" data-toc-modified-id="Practice-Merge-Code-2.8.3"><span class="toc-item-num">2.8.3&nbsp;&nbsp;</span>Practice Merge Code</a></span></li></ul></li></ul></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Feature Engineering</a></span><ul class="toc-item"><li><span><a href="#Features-for-train" data-toc-modified-id="Features-for-train-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Features for train</a></span></li><li><span><a href="#Min_Max-Scaler-Function" data-toc-modified-id="Min_Max-Scaler-Function-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Min_Max Scaler Function</a></span></li><li><span><a href="#Features-for-Test" data-toc-modified-id="Features-for-Test-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Features for Test</a></span></li></ul></li><li><span><a href="#Train-&amp;-Test" data-toc-modified-id="Train-&amp;-Test-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Train &amp; Test</a></span><ul class="toc-item"><li><span><a href="#No-Financials-Model" data-toc-modified-id="No-Financials-Model-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>No Financials Model</a></span><ul class="toc-item"><li><span><a href="#Train,-Test,-Split" data-toc-modified-id="Train,-Test,-Split-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Train, Test, Split</a></span></li><li><span><a href="#Check-train/test-shape" data-toc-modified-id="Check-train/test-shape-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Check train/test shape</a></span></li><li><span><a href="#Train-and-Fit-Model" data-toc-modified-id="Train-and-Fit-Model-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Train and Fit Model</a></span></li><li><span><a href="#Predictions-&amp;-Mean-Absolute-Error" data-toc-modified-id="Predictions-&amp;-Mean-Absolute-Error-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Predictions &amp; Mean Absolute Error</a></span></li><li><span><a href="#RMSE" data-toc-modified-id="RMSE-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>RMSE</a></span></li><li><span><a href="#Feature-Importance" data-toc-modified-id="Feature-Importance-4.1.6"><span class="toc-item-num">4.1.6&nbsp;&nbsp;</span>Feature Importance</a></span></li><li><span><a href="#Summary:-Feature-Importance:" data-toc-modified-id="Summary:-Feature-Importance:-4.1.7"><span class="toc-item-num">4.1.7&nbsp;&nbsp;</span>Summary: Feature Importance:</a></span></li></ul></li><li><span><a href="#Financials-Added-Model" data-toc-modified-id="Financials-Added-Model-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Financials Added Model</a></span><ul class="toc-item"><li><span><a href="#Train,-Test,-Split" data-toc-modified-id="Train,-Test,-Split-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Train, Test, Split</a></span></li><li><span><a href="#Check-train/test-shape" data-toc-modified-id="Check-train/test-shape-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Check train/test shape</a></span></li><li><span><a href="#Train-and-Fit-Model" data-toc-modified-id="Train-and-Fit-Model-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Train and Fit Model</a></span></li><li><span><a href="#Predictions-&amp;-Mean-Absolute-Error" data-toc-modified-id="Predictions-&amp;-Mean-Absolute-Error-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Predictions &amp; Mean Absolute Error</a></span></li><li><span><a href="#RMSE" data-toc-modified-id="RMSE-4.2.5"><span class="toc-item-num">4.2.5&nbsp;&nbsp;</span>RMSE</a></span></li><li><span><a href="#Feature-Importance" data-toc-modified-id="Feature-Importance-4.2.6"><span class="toc-item-num">4.2.6&nbsp;&nbsp;</span>Feature Importance</a></span></li><li><span><a href="#Summary:-Feature-Importance:" data-toc-modified-id="Summary:-Feature-Importance:-4.2.7"><span class="toc-item-num">4.2.7&nbsp;&nbsp;</span>Summary: Feature Importance:</a></span></li></ul></li></ul></li><li><span><a href="#Compare-Models---Multiple-Stocks" data-toc-modified-id="Compare-Models---Multiple-Stocks-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Compare Models - Multiple Stocks</a></span><ul class="toc-item"><li><span><a href="#Only-Price-Information" data-toc-modified-id="Only-Price-Information-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Only Price Information</a></span><ul class="toc-item"><li><span><a href="#Train,-Test,-Split" data-toc-modified-id="Train,-Test,-Split-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Train, Test, Split</a></span></li><li><span><a href="#Check-train/test-shape" data-toc-modified-id="Check-train/test-shape-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Check train/test shape</a></span></li><li><span><a href="#Train-and-Fit-Model" data-toc-modified-id="Train-and-Fit-Model-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Train and Fit Model</a></span></li><li><span><a href="#Predictions-&amp;-Mean-Absolute-Error" data-toc-modified-id="Predictions-&amp;-Mean-Absolute-Error-5.1.4"><span class="toc-item-num">5.1.4&nbsp;&nbsp;</span>Predictions &amp; Mean Absolute Error</a></span></li><li><span><a href="#RMSE" data-toc-modified-id="RMSE-5.1.5"><span class="toc-item-num">5.1.5&nbsp;&nbsp;</span>RMSE</a></span></li><li><span><a href="#Feature-Importance" data-toc-modified-id="Feature-Importance-5.1.6"><span class="toc-item-num">5.1.6&nbsp;&nbsp;</span>Feature Importance</a></span></li><li><span><a href="#Summary:-Feature-Importance:" data-toc-modified-id="Summary:-Feature-Importance:-5.1.7"><span class="toc-item-num">5.1.7&nbsp;&nbsp;</span>Summary: Feature Importance:</a></span></li></ul></li><li><span><a href="#With-Financials" data-toc-modified-id="With-Financials-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>With Financials</a></span><ul class="toc-item"><li><span><a href="#Train,-Test,-Split" data-toc-modified-id="Train,-Test,-Split-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Train, Test, Split</a></span></li><li><span><a href="#Check-train/test-shape" data-toc-modified-id="Check-train/test-shape-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Check train/test shape</a></span></li><li><span><a href="#Train-and-Fit-Model" data-toc-modified-id="Train-and-Fit-Model-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Train and Fit Model</a></span></li><li><span><a href="#Predictions-&amp;-Mean-Absolute-Error" data-toc-modified-id="Predictions-&amp;-Mean-Absolute-Error-5.2.4"><span class="toc-item-num">5.2.4&nbsp;&nbsp;</span>Predictions &amp; Mean Absolute Error</a></span></li><li><span><a href="#RMSE" data-toc-modified-id="RMSE-5.2.5"><span class="toc-item-num">5.2.5&nbsp;&nbsp;</span>RMSE</a></span></li><li><span><a href="#Feature-Importance" data-toc-modified-id="Feature-Importance-5.2.6"><span class="toc-item-num">5.2.6&nbsp;&nbsp;</span>Feature Importance</a></span></li><li><span><a href="#Summary:-Feature-Importance:" data-toc-modified-id="Summary:-Feature-Importance:-5.2.7"><span class="toc-item-num">5.2.7&nbsp;&nbsp;</span>Summary: Feature Importance:</a></span></li></ul></li><li><span><a href="#With-Financials-and-Stock-List" data-toc-modified-id="With-Financials-and-Stock-List-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>With Financials and Stock List</a></span><ul class="toc-item"><li><span><a href="#Train,-Test,-Split" data-toc-modified-id="Train,-Test,-Split-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Train, Test, Split</a></span></li><li><span><a href="#Check-train/test-shape" data-toc-modified-id="Check-train/test-shape-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Check train/test shape</a></span></li><li><span><a href="#Train-and-Fit-Model" data-toc-modified-id="Train-and-Fit-Model-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>Train and Fit Model</a></span></li><li><span><a href="#Predictions-&amp;-Mean-Absolute-Error" data-toc-modified-id="Predictions-&amp;-Mean-Absolute-Error-5.3.4"><span class="toc-item-num">5.3.4&nbsp;&nbsp;</span>Predictions &amp; Mean Absolute Error</a></span></li><li><span><a href="#RMSE" data-toc-modified-id="RMSE-5.3.5"><span class="toc-item-num">5.3.5&nbsp;&nbsp;</span>RMSE</a></span></li><li><span><a href="#Feature-Importance" data-toc-modified-id="Feature-Importance-5.3.6"><span class="toc-item-num">5.3.6&nbsp;&nbsp;</span>Feature Importance</a></span></li><li><span><a href="#Summary:-Feature-Importance:" data-toc-modified-id="Summary:-Feature-Importance:-5.3.7"><span class="toc-item-num">5.3.7&nbsp;&nbsp;</span>Summary: Feature Importance:</a></span></li></ul></li></ul></li><li><span><a href="#GridSearch-Hyper-Parameters" data-toc-modified-id="GridSearch-Hyper-Parameters-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>GridSearch Hyper-Parameters</a></span></li><li><span><a href="#Submission-Prediction---All-Stocks" data-toc-modified-id="Submission-Prediction---All-Stocks-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Submission Prediction - All Stocks</a></span><ul class="toc-item"><li><span><a href="#Create-small-df-for-practice" data-toc-modified-id="Create-small-df-for-practice-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Create small df for practice</a></span></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Feature Engineering</a></span></li><li><span><a href="#Create-df_test-from-feature_test-function" data-toc-modified-id="Create-df_test-from-feature_test-function-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Create df_test from feature_test function</a></span></li><li><span><a href="#Train-&amp;-Test" data-toc-modified-id="Train-&amp;-Test-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Train &amp; Test</a></span><ul class="toc-item"><li><span><a href="#Train,-Test,-Split" data-toc-modified-id="Train,-Test,-Split-7.4.1"><span class="toc-item-num">7.4.1&nbsp;&nbsp;</span>Train, Test, Split</a></span></li></ul></li><li><span><a href="#Check-train/test-shape" data-toc-modified-id="Check-train/test-shape-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Check train/test shape</a></span></li><li><span><a href="#Train-Model" data-toc-modified-id="Train-Model-7.6"><span class="toc-item-num">7.6&nbsp;&nbsp;</span>Train Model</a></span></li><li><span><a href="#Predictions-&amp;-Mean-Absolute-Error" data-toc-modified-id="Predictions-&amp;-Mean-Absolute-Error-7.7"><span class="toc-item-num">7.7&nbsp;&nbsp;</span>Predictions &amp; Mean Absolute Error</a></span></li><li><span><a href="#RMSE" data-toc-modified-id="RMSE-7.8"><span class="toc-item-num">7.8&nbsp;&nbsp;</span>RMSE</a></span></li><li><span><a href="#Feature-Importance" data-toc-modified-id="Feature-Importance-7.9"><span class="toc-item-num">7.9&nbsp;&nbsp;</span>Feature Importance</a></span></li><li><span><a href="#Check-Submission-Score" data-toc-modified-id="Check-Submission-Score-7.10"><span class="toc-item-num">7.10&nbsp;&nbsp;</span>Check Submission Score</a></span></li><li><span><a href="#Scoring-Function" data-toc-modified-id="Scoring-Function-7.11"><span class="toc-item-num">7.11&nbsp;&nbsp;</span>Scoring Function</a></span></li></ul></li><li><span><a href="#Plot-Predictions,-Show-Score" data-toc-modified-id="Plot-Predictions,-Show-Score-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Plot Predictions, Show Score</a></span><ul class="toc-item"><li><span><a href="#Select-56-Dates" data-toc-modified-id="Select-56-Dates-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Select 56 Dates</a></span></li><li><span><a href="#Merge-Financials-and-Stock-List" data-toc-modified-id="Merge-Financials-and-Stock-List-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Merge Financials and Stock List</a></span></li><li><span><a href="#Feature-Engineer-pred_df" data-toc-modified-id="Feature-Engineer-pred_df-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Feature Engineer pred_df</a></span></li><li><span><a href="#One-Stock-df" data-toc-modified-id="One-Stock-df-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>One Stock df</a></span></li><li><span><a href="#Make-Predictions" data-toc-modified-id="Make-Predictions-8.5"><span class="toc-item-num">8.5&nbsp;&nbsp;</span>Make Predictions</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Import Libraries

# %%
# Import necessary libraries
import warnings
warnings.filterwarnings('ignore')

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
# %matplotlib inline
from matplotlib.pylab import rcParams
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
from scipy import stats
import random
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Create data frames

# %%
stock_list = pd.read_csv("gs://cloud-ai-platform-b875a61a-655c-477f-8e45-4ada5ba4908b/stock_list.csv")
#supplemental_prices = pd.read_csv("gs://cloud-ai-platform-b875a61a-655c-477f-8e45-4ada5ba4908b/secondary_stock_prices.csv")
financials = pd.read_csv("gs://cloud-ai-platform-b875a61a-655c-477f-8e45-4ada5ba4908b/financials.csv")
#options = pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/train_files/options.csv")
#sprices = pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/train_files/secondary_stock_prices.csv")
add_prices = pd.read_csv("gs://cloud-ai-platform-b875a61a-655c-477f-8e45-4ada5ba4908b/stock_prices.csv")
#supplemental_sprices = pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/supplemental_files/secondary_stock_prices.csv")
sample_prediction = pd.read_csv('data/sample_submission.csv')

# %%
# make copy of prices df
df = add_prices.copy()

df.head(5)
# Out:
#            RowId        Date  SecuritiesCode    Open    High     Low   Close  \
# 0  20170104_1301  2017-01-04            1301  2734.0  2755.0  2730.0  2742.0
# 1  20170104_1332  2017-01-04            1332   568.0   576.0   563.0   571.0
# 2  20170104_1333  2017-01-04            1333  3150.0  3210.0  3140.0  3210.0
# 3  20170104_1376  2017-01-04            1376  1510.0  1550.0  1510.0  1550.0
# 4  20170104_1377  2017-01-04            1377  3270.0  3350.0  3270.0  3330.0
#
#     Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag    Target
# 0    31400               1.0               NaN            False  0.000730
# 1  2798500               1.0               NaN            False  0.012324
# 2   270800               1.0               NaN            False  0.006154
# 3    11300               1.0               NaN            False  0.011053
# 4   150800               1.0               NaN            False  0.003026

# %% [markdown]
# ## Create Train and Test df's

# %%
# make copy of df
df1 = df.copy()

df1
# Out:
#                  RowId        Date  SecuritiesCode    Open    High     Low  \
# 0        20170104_1301  2017-01-04            1301  2734.0  2755.0  2730.0
# 1        20170104_1332  2017-01-04            1332   568.0   576.0   563.0
# 2        20170104_1333  2017-01-04            1333  3150.0  3210.0  3140.0
# 3        20170104_1376  2017-01-04            1376  1510.0  1550.0  1510.0
# 4        20170104_1377  2017-01-04            1377  3270.0  3350.0  3270.0
# ...                ...         ...             ...     ...     ...     ...
# 2332526  20211203_9990  2021-12-03            9990   514.0   528.0   513.0
# 2332527  20211203_9991  2021-12-03            9991   782.0   794.0   782.0
# 2332528  20211203_9993  2021-12-03            9993  1690.0  1690.0  1645.0
# 2332529  20211203_9994  2021-12-03            9994  2388.0  2396.0  2380.0
# 2332530  20211203_9997  2021-12-03            9997   690.0   711.0   686.0
#
# ...

# %%
test_set
# Out:
#                  RowId        Date  SecuritiesCode    Open    High     Low  \
# 2330531  20211203_1301  2021-12-03            1301  2983.0  2983.0  2965.0
# 2330532  20211203_1332  2021-12-03            1332   579.0   585.0   570.0
# 2330533  20211203_1333  2021-12-03            1333  2333.0  2358.0  2315.0
# 2330534  20211203_1375  2021-12-03            1375  1222.0  1236.0  1218.0
# 2330535  20211203_1376  2021-12-03            1376  1370.0  1370.0  1321.0
# ...                ...         ...             ...     ...     ...     ...
# 2332526  20211203_9990  2021-12-03            9990   514.0   528.0   513.0
# 2332527  20211203_9991  2021-12-03            9991   782.0   794.0   782.0
# 2332528  20211203_9993  2021-12-03            9993  1690.0  1690.0  1645.0
# 2332529  20211203_9994  2021-12-03            9994  2388.0  2396.0  2380.0
# 2332530  20211203_9997  2021-12-03            9997   690.0   711.0   686.0
#
# ...

# %% [markdown]
# ## Modify sample_prediction for testing

# %%
sample_prediction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112000 entries, 0 to 111999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Date            112000 non-null  object
#  1   SecuritiesCode  112000 non-null  int64
#  2   Rank            112000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 2.6+ MB

# %%
# Copy Sample Prediction
sp_copy = sample_prediction.copy()

sp_copy = sp_copy.loc[:1999]
sp_copy
# Out:
#             Date  SecuritiesCode  Rank
# 0     2021-12-06            1301     0
# 1     2021-12-06            1332     1
# 2     2021-12-06            1333     2
# 3     2021-12-06            1375     3
# 4     2021-12-06            1376     4
# ...          ...             ...   ...
# 1995  2021-12-06            9990  1995
# 1996  2021-12-06            9991  1996
# 1997  2021-12-06            9993  1997
# 1998  2021-12-06            9994  1998
# 1999  2021-12-06            9997  1999
#
# [2000 rows x 3 columns]

# %%
sp_copy = sp_copy.replace({'2021-12-06': '2021-12-03'})
sp_copy
# Out:
#             Date  SecuritiesCode  Rank
# 0     2021-12-03            1301     0
# 1     2021-12-03            1332     1
# 2     2021-12-03            1333     2
# 3     2021-12-03            1375     3
# 4     2021-12-03            1376     4
# ...          ...             ...   ...
# 1995  2021-12-03            9990  1995
# 1996  2021-12-03            9991  1996
# 1997  2021-12-03            9993  1997
# 1998  2021-12-03            9994  1998
# 1999  2021-12-03            9997  1999
#
# [2000 rows x 3 columns]

# %% [markdown]
# ## Identify Single Stock

# %%
# Pull one stock's values for given stock from stock_prices
values8103 = df1.loc[df1['SecuritiesCode'] == 8103]                   
values8103.head(2)
# Out:
#               RowId        Date  SecuritiesCode   Open   High    Low  Close  \
# 1450  20170104_8103  2017-01-04            8103  406.0  413.0  395.0  413.0
# 3315  20170105_8103  2017-01-05            8103  415.0  419.0  408.0  413.0
#
#       Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag    Target
# 1450   82600               1.0               NaN            False -0.024213
# 3315   57500               1.0               NaN            False -0.002481

# %%
values8103__ = values8103.copy()

#values8103__['Date'] = pd.to_datetime(values8103__['Date'], format='%Y/%m/%d', errors='coerce')
#mask = values8103__['Date'].isnull()
#values8103__.loc[mask, 'Date'] = pd.to_datetime(values8103__['Date'], format='%Y/%m/%d',
 #                                                errors='coerce')
    
values8103__['Date'] = df['Date'].str.replace('-', '')
values8103__['Date'] = values8103__['Date'].astype(float)
values8103__
# Out:
#                  RowId        Date  SecuritiesCode   Open   High    Low  \
# 1450     20170104_8103  20170104.0            8103  406.0  413.0  395.0
# 3315     20170105_8103  20170105.0            8103  415.0  419.0  408.0
# 5180     20170106_8103  20170106.0            8103  404.0  410.0  401.0
# 7045     20170110_8103  20170110.0            8103  404.0  408.0  398.0
# 8910     20170111_8103  20170111.0            8103  405.0  405.0  390.0
# ...                ...         ...             ...    ...    ...    ...
# 2324104  20211129_8103  20211129.0            8103  829.0  843.0  825.0
# 2326104  20211130_8103  20211130.0            8103  839.0  846.0  818.0
# 2328104  20211201_8103  20211201.0            8103  822.0  833.0  819.0
# 2330104  20211202_8103  20211202.0            8103  828.0  832.0  818.0
# 2332104  20211203_8103  20211203.0            8103  825.0  840.0  825.0
#
#          Close  Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag  \
# ...

# %% [markdown]
# ## Explore Columns
# * AdjustmentFactor
# * Expected Divident
# * SupervisionFlag

# %% [markdown]
# ### How many null values in each column?

# %%
values8103.isna().sum()
# Out:
# RowId                  0
# Date                   0
# SecuritiesCode         0
# Open                   1
# High                   1
# Low                    1
# Close                  1
# Volume                 0
# AdjustmentFactor       0
# ExpectedDividend    1192
# SupervisionFlag        0
# Target                 0
# dtype: int64

# %% [markdown]
# #### Forward Fill
# * All Columns except ExpectedDividend

# %%
cols = ['Open', 'High', 'Low', 'Close']
values8103.loc[:,cols] = values8103.loc[:,cols].ffill()
values8103.loc[:,cols] = values8103.loc[:,cols].bfill()
values8103.isna().sum()
# Out:
# RowId                  0
# Date                   0
# SecuritiesCode         0
# Open                   0
# High                   0
# Low                    0
# Close                  0
# Volume                 0
# AdjustmentFactor       0
# ExpectedDividend    1192
# SupervisionFlag        0
# Target                 0
# dtype: int64

# %% [markdown]
# ### Describe sparse and singular value columns

# %%
values8103['ExpectedDividend'].describe()
# Out:
# count    10.000000
# mean     14.600000
# std      17.147724
# min       0.000000
# 25%       2.000000
# 50%      10.000000
# 75%      14.250000
# max      47.000000
# Name: ExpectedDividend, dtype: float64

# %%
values8103['AdjustmentFactor'].describe()
# Out:
# count    1202.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
# Name: AdjustmentFactor, dtype: float64

# %%
values8103['SupervisionFlag'].describe()
# Out:
# count      1202
# unique        1
# top       False
# freq       1202
# Name: SupervisionFlag, dtype: object

# %% [markdown]
# ## Plot Attributes

# %% [markdown]
# ### Plot Daily Close
# * Observe multiplicative trend?

# %%
close8103 = values8103.copy()
close8103 = close8103.iloc[:, [1,6]]

time = (close8103['Date'] > '2019-12-03') & (close8103['Date'] <= '2021-12-03')
close8103 = close8103.loc[time]

# Plot the timeseries 
pd.plotting.register_matplotlib_converters()
ax = close8103.set_index('Date').plot(figsize=(15, 8), linewidth=2)
ax.set_ylabel('Close Price')
ax.set_xlabel('Date')


plt.show()

# %% [markdown]
# ## Plot Target

# %%
target_8103 = values8103.copy()
target_8103 = target_8103.iloc[:, [1,11]]

time = (target_8103['Date'] > '2019-12-03') & (target_8103['Date'] <= '2021-12-03')
target_8103 = target_8103.loc[time]

# Plot the timeseries 
pd.plotting.register_matplotlib_converters()
ax = target_8103.set_index('Date').plot(figsize=(15, 8), linewidth=2)
ax.set_ylabel('Sharpe Ratio')
ax.set_xlabel('Date')

plt.show()

# %% [markdown]
# ## Zoom in on Target and Close

# %% [markdown]
# ### Close

# %%
close8103 = values8103.copy()
close8103 = close8103.iloc[:, [1,6]]

time = (close8103['Date'] > '2021-08-15') & (close8103['Date'] <= '2021-12-03')
close8103 = close8103.loc[time]

# Plot the timeseries 
pd.plotting.register_matplotlib_converters()
ax = close8103.set_index('Date').plot(figsize=(15, 8), linewidth=2)
ax.set_ylabel('Close Price')
ax.set_xlabel('Date')

plt.show()

# %% [markdown]
# ### Target

# %%
target_8103 = values8103.copy()
target_8103 = target_8103.iloc[:, [1,11]]

time = (target_8103['Date'] > '2021-08-15') & (target_8103['Date'] <= '2021-12-03')
target_8103 = target_8103.loc[time]

# Plot the timeseries 
pd.plotting.register_matplotlib_converters()
ax = target_8103.set_index('Date').plot(figsize=(15, 8), linewidth=2)
ax.set_ylabel('Sharpe Ratio')
ax.set_xlabel('Date')

plt.show()

# %% [markdown]
# ## Summary:
# * The target - Sharpe Ratio - changes in the correct direction before the close price change, which signifies that the target is able to predict stock price changes.

# %% [markdown]
# ## Add Financials

# %% [markdown]
# ### Merge Function

# %%
def financial_merge(financials, prices):
    # Reduce financials to important features
    fin4 = financials[['Date',
                       'SecuritiesCode',
                       'EarningsPerShare', 
                       'TotalAssets', 
                       'ForecastProfit',
                       'ForecastEarningsPerShare',
                       'NetSales',
                       'EquityToAssetRatio']]

    # Drop rows with nan securities code
    fin4 = fin4.dropna(subset=['SecuritiesCode'])

    # Convert fin SecuritiesCode to int
    fin4['SecuritiesCode'] = fin4['SecuritiesCode'].astype(int)

    df1_copy = prices.copy()

    # Drop rows with null values
    fin_all = fin4.dropna(axis=0)

    # Convert financial data to numeric
    fin_all.ForecastProfit = pd.to_numeric(fin_all.ForecastProfit, errors ='coerce').fillna(0).astype('float')
    fin_all.ForecastEarningsPerShare = pd.to_numeric(fin_all.ForecastEarningsPerShare, errors ='coerce').fillna(0).astype('float')
    fin_all.EarningsPerShare = pd.to_numeric(fin_all.EarningsPerShare, errors ='coerce').fillna(0).astype('float')
    fin_all.TotalAssets = pd.to_numeric(fin_all.TotalAssets, errors ='coerce').fillna(0).astype('float')
    fin_all.NetSales = pd.to_numeric(fin_all.NetSales, errors ='coerce').fillna(0).astype('float')
    fin_all.EquityToAssetRatio = pd.to_numeric(fin_all.EquityToAssetRatio, errors ='coerce').fillna(0).astype('float')

    # Create list of all securities codes
    all_stocks_list = prices['SecuritiesCode'].values.tolist()

    # Iterate over stock list to pull only desired stocks from financials
    fin_all = fin_all[fin_all['SecuritiesCode'].isin(all_stocks_list)]

    # Merge Stock Prices with Financials
    fin_added = pd.merge(df1_copy, fin_all, how='left', on=["Date", "SecuritiesCode"])

    return fin_added

# %% [markdown]
# #### Merge Financials with df1

# %%
fin_merge_df1 = financial_merge(financials, df1)
fin_merge_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2332761 entries, 0 to 2332760
# Data columns (total 18 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   RowId                     object
#  1   Date                      object
#  2   SecuritiesCode            int64
#  3   Open                      float64
#  4   High                      float64
#  5   Low                       float64
#  6   Close                     float64
#  7   Volume                    int64
#  8   AdjustmentFactor          float64
#  9   ExpectedDividend          float64
#  10  SupervisionFlag           bool
#  11  Target                    float64
#  12  EarningsPerShare          float64
#  13  TotalAssets               float64
#  14  ForecastProfit            float64
#  15  ForecastEarningsPerShare  float64
#  16  NetSales                  float64
#  17  EquityToAssetRatio        float64
# dtypes: bool(1), float64(13), int64(2), object(2)
# ...

# %% [markdown]
# ## Add Stock List

# %% [markdown]
# ### Merge Function

# %%
def stock_list_merge(stock_list, merge):
    
    # Replace non-integer character in 33SectorCode
    stock_list['33SectorCode'] = stock_list['33SectorCode'].replace('-', 0)

    # Choose features from stock_list to merge
    stock_list_cond = stock_list[['SecuritiesCode', '33SectorCode','MarketCapitalization','IssuedShares']]
    stock_list_cond[['33SectorCode',
                     'MarketCapitalization',
                     'IssuedShares']] = stock_list_cond[
                                    ['33SectorCode',
                                     'MarketCapitalization',
                                     'IssuedShares']].astype(float)

    # Create list of all securities codes
    all_stocks_list = merge['SecuritiesCode'].values.tolist()

    # Create stock list df with all_stocks_list
    stock_list_cond = stock_list_cond.loc[stock_list_cond['SecuritiesCode'].isin(all_stocks_list)]

    # Merge Stock List with Stock Prices and Financials df
    final = pd.merge(merge, stock_list_cond, how='left', on=["SecuritiesCode"])

    return final

# %%
stock_merge_df1 = stock_list_merge(stock_list, fin_merge_df1)
stock_merge_df1
# Out:
#                  RowId        Date  SecuritiesCode    Open    High     Low  \
# 0        20170104_1301  2017-01-04            1301  2734.0  2755.0  2730.0
# 1        20170104_1332  2017-01-04            1332   568.0   576.0   563.0
# 2        20170104_1333  2017-01-04            1333  3150.0  3210.0  3140.0
# 3        20170104_1376  2017-01-04            1376  1510.0  1550.0  1510.0
# 4        20170104_1377  2017-01-04            1377  3270.0  3350.0  3270.0
# ...                ...         ...             ...     ...     ...     ...
# 2332756  20211203_9990  2021-12-03            9990   514.0   528.0   513.0
# 2332757  20211203_9991  2021-12-03            9991   782.0   794.0   782.0
# 2332758  20211203_9993  2021-12-03            9993  1690.0  1690.0  1645.0
# 2332759  20211203_9994  2021-12-03            9994  2388.0  2396.0  2380.0
# 2332760  20211203_9997  2021-12-03            9997   690.0   711.0   686.0
#
# ...

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Features Train without Financials

# %%
def feature_train(train):
    
    #train = train.groupby("SecuritiesCode")
    
    # Add Lag Features
    lag_features = ["High", "Low", "Volume", "Close", "Open"]
    df_rolled_7d = train[lag_features].rolling(window=4, min_periods=0)
    df_mean_7d = df_rolled_7d.mean().shift(1).reset_index().astype(np.float32)
    df_mean_7d = df_mean_7d.drop('index', axis=1)
    df_mean_7d = df_mean_7d.fillna(0)
    df_mean_7d = df_mean_7d.round(2)
    df_mean_7d['High_lag_1'] = df_mean_7d['High']
    df_mean_7d['Open_lag_1'] = df_mean_7d['Open']
    df_mean_7d['Close_lag_1'] = df_mean_7d['Close']
    df_mean_7d['Volume_lag_1'] = df_mean_7d['Volume']
    df_mean_7d['Low_lag_1'] = df_mean_7d['Low']
    df_mean_7d = df_mean_7d.drop(["High", "Low", "Volume", "Close", "Open"], axis=1)
    train = train.reset_index(drop=True)
    train = pd.concat([train, df_mean_7d], axis=1)
    
    # Set Datetime index
    #train['Date'] = pd.to_datetime(train['Date'], format='%Y/%m/%d', errors='coerce')
    #mask = train['Date'].isnull()
    #train.loc[mask, 'Date'] = pd.to_datetime(train['Date'], format='%Y/%m/%d',
    #                                            errors='coerce')
    
    train['Date'] = train['Date'].str.replace('-', '')
    train['Date'] = train['Date'].astype(float)
    
    # Drop irrelevant columns for training
    train = train.drop(
                        ['RowId', 
                         'ExpectedDividend', 
                         'SupervisionFlag',
                         'AdjustmentFactor'], axis=1)
    
    # Bool to int for SupervisionFlag
    #train["SupervisionFlag"] = train["SupervisionFlag"].astype(int)
    
    # Forward, then backward fill missing values in cols
    cols = ['Open', 
            'High', 
            'Low', 
            'Close',
           'Target']
    train.loc[:,cols] = train.loc[:,cols].bfill()
    train.loc[:,cols] = train.loc[:,cols].ffill()
    
    # Replace missing values in ExpectedDividend with 0
    #train['ExpectedDividend'] = train['ExpectedDividend'].fillna(0)
    
    # Add Spread Features
    train['Daily_Spread'] = train['Close'] - train['Open']
    train['Daily_Max_Min'] = train['High'] - train['Low']
    train['1_Day_Spread'] = train['Close'].diff()
    train['2_Day_Spread'] = train['Close'].diff(periods=2)
    train['1_Week_Spread'] = train['Close'].diff(periods=5)
    #train['MA_Prior_1day'] = train['Close'].diff(periods= -1)
    #train['MA_Prior_2day'] = train['Close'].diff(periods= -2)
    train = train.fillna(0)
    #train['MA_Prior_diff'] = train['MA_Prior_1day'] - train['MA_Prior_2day']
    train['Return_Lag_1'] = (train['Close'] - train['1_Day_Spread'])/train['Close']
        

    # Fill missing and inf/-inf values with 0
    train.replace([np.inf, -np.inf], 0, inplace=True)
    train = train.fillna(0)
        
    # Add rolling ratio of mean/std of forward 1 day return
    indexer = pd.api.indexers.FixedForwardWindowIndexer(window_size=5)
    train['ExPost_SR'] = (train['Return_Lag_1'].rolling(
        window=indexer, min_periods=1).mean())/(
        train['Return_Lag_1'].std())
    
    # Fill missing and inf/-inf values with 0
    train.replace([np.inf, -np.inf], 0, inplace=True)
    train = train.fillna(0)
    
    # Fill missing values with 0
    #train = train.fillna(0)
    
    return train

# %% [markdown]
# ## Feature Train - Financials Added

# %%
def feature_train_financials(train):
    
    #train = train.groupby("SecuritiesCode")
    
    # Add Lag Features
    lag_features = ["High", "Low", "Volume", "Close", "Open"]
    df_rolled_7d = train[lag_features].rolling(window=4, min_periods=0)
    df_mean_7d = df_rolled_7d.mean().shift(1).reset_index().astype(np.float32)
    df_mean_7d = df_mean_7d.drop('index', axis=1)
    df_mean_7d = df_mean_7d.fillna(0)
    df_mean_7d = df_mean_7d.round(2)
    df_mean_7d['High_lag_1'] = df_mean_7d['High']
    df_mean_7d['Open_lag_1'] = df_mean_7d['Open']
    df_mean_7d['Close_lag_1'] = df_mean_7d['Close']
    df_mean_7d['Volume_lag_1'] = df_mean_7d['Volume']
    df_mean_7d['Low_lag_1'] = df_mean_7d['Low']
    df_mean_7d = df_mean_7d.drop(["High", "Low", "Volume", "Close", "Open"], axis=1)
    train = train.reset_index(drop=True)
    train = pd.concat([train, df_mean_7d], axis=1)
    
    # Set Datetime index
    #train['Date'] = pd.to_datetime(train['Date'], format='%Y/%m/%d', errors='coerce')
    #mask = train['Date'].isnull()
    #train.loc[mask, 'Date'] = pd.to_datetime(train['Date'], format='%Y/%m/%d',
    #                                            errors='coerce')
    
    train['Date'] = train['Date'].str.replace('-', '')
    train['Date'] = train['Date'].astype(float)
    
    # Drop irrelevant columns for training
    train = train.drop(
                        ['RowId', 
                         'ExpectedDividend', 
                         'SupervisionFlag',
                         'AdjustmentFactor'], axis=1)
    
    # Bool to int for SupervisionFlag
    #train["SupervisionFlag"] = train["SupervisionFlag"].astype(int)
    
    # Forward, then backward fill missing values in cols
    cols = ['Open', 
            'High', 
            'Low', 
            'Close',
           'Target',
            'EarningsPerShare', 
            'TotalAssets', 
            'ForecastProfit',
            'ForecastEarningsPerShare',
            'NetSales',
            'EquityToAssetRatio']
    train.loc[:,cols] = train.loc[:,cols].bfill()
    train.loc[:,cols] = train.loc[:,cols].ffill()
    
    # Replace missing values in ExpectedDividend with 0
    #train['ExpectedDividend'] = train['ExpectedDividend'].fillna(0)
    
    # Add Spread Features
    train['Daily_Spread'] = train['Close'] - train['Open']
    train['Daily_Max_Min'] = train['High'] - train['Low']
    train['1_Day_Spread'] = train['Close'].diff()
    train['2_Day_Spread'] = train['Close'].diff(periods=2)
    train['1_Week_Spread'] = train['Close'].diff(periods=5)
    #train['MA_Prior_1day'] = train['Close'].diff(periods= -1)
    #train['MA_Prior_2day'] = train['Close'].diff(periods= -2)
    train = train.fillna(0)
    #train['MA_Prior_diff'] = train['MA_Prior_1day'] - train['MA_Prior_2day']
    train['Return_Lag_1'] = (train['Close'] - train['1_Day_Spread'])/train['Close']
        

    # Fill missing and inf/-inf values with 0
    train.replace([np.inf, -np.inf], 0, inplace=True)
    train = train.fillna(0)
        
    # Add rolling ratio of mean/std of forward 1 day return
    indexer = pd.api.indexers.FixedForwardWindowIndexer(window_size=5)
    train['ExPost_SR'] = (train['Return_Lag_1'].rolling(
        window=indexer, min_periods=1).mean())/(
        train['Return_Lag_1'].std())
    
    # Fill missing and inf/-inf values with 0
    train.replace([np.inf, -np.inf], 0, inplace=True)
    train = train.fillna(0)
    
    # Fill missing values with 0
    #train = train.fillna(0)
    
    return train

# %% [markdown]
# ## Min_Max Scaler Function

# %%
def min_max(df):
    # MinMax Scale columns (-1, 1 scale)   
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaled = scaler.fit_transform(df)
    train_cols = df.columns.values.tolist()
    trained = pd.DataFrame(data=scaled, columns=train_cols, index=df.index)
    return trained

# %% [markdown]
# # Plotting Function

# %%
def plot(X_test, predictions, y_test):
    
    # df with Predictions and Target
    date_df = X_test.Date
    date_df = pd.DataFrame(date_df)
    date_df['Predictions'] = predictions
    date_df['Target'] = y_test
    
    # Drop Date
    date_df = date_df.drop('Date', axis=1)
    date_df = date_df.reset_index(drop=True)

    sns.set(rc={'figure.figsize':(11.7,8.27)})

    sns.set_theme(style="white", palette='bright', font_scale=2)

    ax = sns.lineplot(data=date_df, 
                          palette="bright", 
                          markers=False, 
                          dashes=False).set(title='Sharpe Ratio Predictions', 
                                            xlabel="Trading Days",
                                            ylabel= "Sharpe Ratio (norm.)"
                                            )
    sns.despine()

    x = plt.show()
    
    return x

# %% [markdown]
# # Feature Engineer Data Frames

# %% [markdown]
# ## Prices Only

# %%
# Groupby for feature engineering by securities code
prices = df1.groupby("SecuritiesCode").apply(feature_train)

# reset index
prices = prices.reset_index(drop=True)

# Create Securities Code df
sec_code_df = prices['SecuritiesCode']
sec_code_df = pd.DataFrame(sec_code_df)

# min max scale prices df
prices = min_max(prices)

# drop SecuritiesCode column before adding it back
prices = prices.drop('SecuritiesCode', axis=1)

# Concat dfs together
prices = pd.concat([sec_code_df, prices], axis=1)

# Sort df by date
prices = prices.sort_values(by='Date')

prices
# Out:
#          SecuritiesCode  Date      Open      High       Low     Close  \
# 0                  1301  -1.0 -0.950517 -0.950401 -0.949304 -0.950190
# 1861349            8185  -1.0 -0.949316 -0.948735 -0.948277 -0.948291
# 285188             2698  -1.0 -0.968054 -0.967996 -0.967328 -0.967791
# 1860147            8182  -1.0 -0.973294 -0.972901 -0.972590 -0.972685
# 286390             2702  -1.0 -0.944040 -0.944336 -0.943333 -0.944384
# ...                 ...   ...       ...       ...       ...       ...
# 1081191            5951   1.0 -0.986410 -0.986423 -0.986398 -0.986324
# 1716150            7864   1.0 -0.962360 -0.962076 -0.961618 -0.961729
# 372200             3064   1.0 -0.960795 -0.959995 -0.960126 -0.959630
# 2235168            9692   1.0 -0.977696 -0.977427 -0.977199 -0.977213
# 2332530            9997   1.0 -0.987702 -0.987401 -0.987443 -0.987547
#
#            Volume    Target  High_lag_1  Open_lag_1  Close_lag_1  \
# ...

# %% [markdown]
# ### Correlation Heat Map

# %%
d = prices.corr()
sns.heatmap(d);

# %% [markdown]
# ## Summary:
# * SecuritiesCode and ExPost_SR bear the slightest negative correlation with Target.

# %% [markdown]
# ## Prices + Financials

# %%
# Groupby for feature engineering by securities code
fin_df = fin_merge_df1.groupby("SecuritiesCode").apply(feature_train)

# reset index
fin_df = fin_df.reset_index(drop=True)

# Create Securities Code df
sec_code_df = fin_df['SecuritiesCode']
sec_code_df = pd.DataFrame(sec_code_df)

# min max scale prices df
fin_df = min_max(fin_df)

# drop SecuritiesCode column before adding it back
fin_df = fin_df.drop('SecuritiesCode', axis=1)

# Concat dfs together
fin_df = pd.concat([sec_code_df, fin_df], axis=1)

# Sort df by date
fin_df = fin_df.sort_values(by='Date')

fin_df
# Out:
#          SecuritiesCode  Date      Open      High       Low     Close  \
# 0                  1301  -1.0 -0.950517 -0.950401 -0.949304 -0.950190
# 2284676            9843  -1.0 -0.756476 -0.756075 -0.751518 -0.755952
# 599902             3926  -1.0 -0.943494 -0.943703 -0.943799 -0.944657
# 1340402            6644  -1.0 -0.978151 -0.978078 -0.977796 -0.977980
# 1341604            6645  -1.0 -0.917661 -0.916278 -0.915531 -0.915809
# ...                 ...   ...       ...       ...       ...       ...
# 403501             3153   1.0 -0.983663 -0.983473 -0.983226 -0.983330
# 1673024            7732   1.0 -0.968964 -0.968557 -0.968354 -0.968613
# 404703             3154   1.0 -0.983936 -0.983581 -0.983505 -0.983476
# 1670620            7730   1.0 -0.971165 -0.970421 -0.970631 -0.970238
# 2332760            9997   1.0 -0.987702 -0.987401 -0.987443 -0.987547
#
#            Volume    Target  EarningsPerShare  TotalAssets  ...  Close_lag_1  \
# ...

# %%
d = fin_df.corr()
sns.heatmap(d);

# %% [markdown]
# ## Prices + Financials + Stock List

# %%
# Groupby for feature engineering by securities code
stock_list_df = stock_merge_df1.groupby("SecuritiesCode").apply(feature_train_financials)

# reset index
stock_list_df = stock_list_df.reset_index(drop=True)

# Create Securities Code df
sec_code_df = stock_list_df['SecuritiesCode']
sec_code_df = pd.DataFrame(sec_code_df)

# min max scale prices df
stock_list_df = min_max(stock_list_df)

# drop SecuritiesCode column before adding it back
stock_list_df = stock_list_df.drop('SecuritiesCode', axis=1)

# Concat dfs together
stock_list_df = pd.concat([sec_code_df, stock_list_df], axis=1)

# Sort df by date
stock_list_df = stock_list_df.sort_values(by='Date')

stock_list_df
# Out:
#          SecuritiesCode  Date      Open      High       Low     Close  \
# 0                  1301  -1.0 -0.950517 -0.950401 -0.949304 -0.950190
# 2284676            9843  -1.0 -0.756476 -0.756075 -0.751518 -0.755952
# 599902             3926  -1.0 -0.943494 -0.943703 -0.943799 -0.944657
# 1340402            6644  -1.0 -0.978151 -0.978078 -0.977796 -0.977980
# 1341604            6645  -1.0 -0.917661 -0.916278 -0.915531 -0.915809
# ...                 ...   ...       ...       ...       ...       ...
# 403501             3153   1.0 -0.983663 -0.983473 -0.983226 -0.983330
# 1673024            7732   1.0 -0.968964 -0.968557 -0.968354 -0.968613
# 404703             3154   1.0 -0.983936 -0.983581 -0.983505 -0.983476
# 1670620            7730   1.0 -0.971165 -0.970421 -0.970631 -0.970238
# 2332760            9997   1.0 -0.987702 -0.987401 -0.987443 -0.987547
#
#            Volume    Target  EarningsPerShare  TotalAssets  ...  Close_lag_1  \
# ...

# %% [markdown]
# # Train & Test

# %% [markdown]
# ## No Financials Model

# %% [markdown]
# ### Train, Test, Split

# %%
prices
# Out:
#          SecuritiesCode  Date      Open      High       Low     Close  \
# 0                  1301  -1.0 -0.950517 -0.950401 -0.949304 -0.950190
# 1861349            8185  -1.0 -0.949316 -0.948735 -0.948277 -0.948291
# 285188             2698  -1.0 -0.968054 -0.967996 -0.967328 -0.967791
# 1860147            8182  -1.0 -0.973294 -0.972901 -0.972590 -0.972685
# 286390             2702  -1.0 -0.944040 -0.944336 -0.943333 -0.944384
# ...                 ...   ...       ...       ...       ...       ...
# 1081191            5951   1.0 -0.986410 -0.986423 -0.986398 -0.986324
# 1716150            7864   1.0 -0.962360 -0.962076 -0.961618 -0.961729
# 372200             3064   1.0 -0.960795 -0.959995 -0.960126 -0.959630
# 2235168            9692   1.0 -0.977696 -0.977427 -0.977199 -0.977213
# 2332530            9997   1.0 -0.987702 -0.987401 -0.987443 -0.987547
#
#            Volume    Target  High_lag_1  Open_lag_1  Close_lag_1  \
# ...

# %%
one_stock = prices.loc[prices['SecuritiesCode'] == 8103] 

one_stock
# Out:
#          SecuritiesCode      Date      Open      High       Low     Close  \
# 1822885            8103 -1.000000 -0.992869 -0.992795 -0.992872 -0.992715
# 1822886            8103 -0.999951 -0.992705 -0.992687 -0.992630 -0.992715
# 1822887            8103 -0.999903 -0.992905 -0.992850 -0.992760 -0.992897
# 1822888            8103 -0.999708 -0.992905 -0.992886 -0.992816 -0.992916
# 1822889            8103 -0.999659 -0.992887 -0.992940 -0.992966 -0.993043
# ...                 ...       ...       ...       ...       ...       ...
# 1824082            8103  0.996399 -0.985173 -0.985012 -0.984849 -0.985137
# 1824083            8103  0.996448 -0.984991 -0.984957 -0.984980 -0.985302
# 1824084            8103  0.999903 -0.985301 -0.985193 -0.984961 -0.985174
# 1824085            8103  0.999951 -0.985191 -0.985211 -0.984980 -0.985174
# 1824086            8103  1.000000 -0.985246 -0.985066 -0.984849 -0.984936
#
#            Volume    Target  High_lag_1  Open_lag_1  Close_lag_1  \
# ...

# %%
# Split df into train/test
column_indices = {name: i for i, name in enumerate(one_stock.columns)}

n = len(one_stock)
train_df = one_stock[0:int(n*0.9)]
test_df = one_stock[int(n*0.9):]

print('Training Shape:', train_df.shape)
print('Test Shape:', test_df.shape)
# Out:
# Training Shape: (1081, 20)
# Test Shape: (121, 20)

# %%
# create Train X and y df's
X_train = train_df.drop('Target', axis=1)
y_train = train_df['Target']

# create Test X and y df's
X_test = test_df.drop('Target', axis=1)
y_test = test_df['Target']

# %%
X_test
# Out:
#          SecuritiesCode      Date      Open      High       Low     Close  \
# 1823966            8103  0.971094 -0.991541 -0.991601 -0.991361 -0.991546
# 1823967            8103  0.971143 -0.991595 -0.991637 -0.991398 -0.991583
# 1823968            8103  0.971192 -0.991595 -0.991637 -0.991436 -0.991601
# 1823969            8103  0.971338 -0.991668 -0.991691 -0.991436 -0.991601
# 1823970            8103  0.971386 -0.991686 -0.991691 -0.991473 -0.991656
# ...                 ...       ...       ...       ...       ...       ...
# 1824082            8103  0.996399 -0.985173 -0.985012 -0.984849 -0.985137
# 1824083            8103  0.996448 -0.984991 -0.984957 -0.984980 -0.985302
# 1824084            8103  0.999903 -0.985301 -0.985193 -0.984961 -0.985174
# 1824085            8103  0.999951 -0.985191 -0.985211 -0.984980 -0.985174
# 1824086            8103  1.000000 -0.985246 -0.985066 -0.984849 -0.984936
#
#            Volume  High_lag_1  Open_lag_1  Close_lag_1  Volume_lag_1  \
# ...

# %% [markdown]
# ### Train and Fit Model

# %%
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(random_state = 42)

# Train the model on training data
rf.fit(X_train, y_train);

# %% [markdown]
# ### Predictions & Mean Absolute Error

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(X_test)

# Calculate the absolute errors
errors = abs(predictions - y_test)

# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'of the Sharpe Ratio')
# Out:
# Mean Absolute Error: 0.02 of the Sharpe Ratio

# %% [markdown]
# ### RMSE

# %%
# evaluate forecasts
rmse = sqrt(mean_squared_error(y_test, predictions))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.066

# %% [markdown]
# ### Feature Importance

# %%
# Saving feature names
feature_list = list(X_train.columns)

# Get numerical feature importances
importances = list(rf.feature_importances_)

# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]

# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: ExPost_SR            Importance: 0.39
# Variable: Return_Lag_1         Importance: 0.07
# Variable: Daily_Spread         Importance: 0.06
# Variable: 1_Week_Spread        Importance: 0.06
# Variable: Date                 Importance: 0.05
# Variable: Volume               Importance: 0.05
# Variable: Volume_lag_1         Importance: 0.05
# Variable: Open                 Importance: 0.04
# Variable: Daily_Max_Min        Importance: 0.04
# Variable: 2_Day_Spread         Importance: 0.04
# Variable: 1_Day_Spread         Importance: 0.03
# Variable: High                 Importance: 0.02
# Variable: Low                  Importance: 0.02
# Variable: Close                Importance: 0.02
# Variable: Open_lag_1           Importance: 0.02
# Variable: Close_lag_1          Importance: 0.02
# Variable: Low_lag_1            Importance: 0.02
# Variable: High_lag_1           Importance: 0.01
# Variable: SecuritiesCode       Importance: 0.0

# %% [markdown]
# ### Plot Predictions vs Actual

# %%
plot(X_test, predictions, y_test)

# %% [markdown]
# ### Summary:
# * Ex_Post Sharpe Ratio and Return from prior day seem to be most important influencers when predicting Sharpe Ratio.

# %% [markdown]
# ## Financials Added Model

# %% [markdown]
# ### Train, Test, Split

# %%
one_stock = fin_df.loc[fin_df['SecuritiesCode'] == 8103] 

one_stock
# Out:
#          SecuritiesCode      Date      Open      High       Low     Close  \
# 1823071            8103 -1.000000 -0.992869 -0.992795 -0.992872 -0.992715
# 1823072            8103 -0.999951 -0.992705 -0.992687 -0.992630 -0.992715
# 1823073            8103 -0.999903 -0.992905 -0.992850 -0.992760 -0.992897
# 1823074            8103 -0.999708 -0.992905 -0.992886 -0.992816 -0.992916
# 1823075            8103 -0.999659 -0.992887 -0.992940 -0.992966 -0.993043
# ...                 ...       ...       ...       ...       ...       ...
# 1824268            8103  0.996399 -0.985173 -0.985012 -0.984849 -0.985137
# 1824269            8103  0.996448 -0.984991 -0.984957 -0.984980 -0.985302
# 1824270            8103  0.999903 -0.985301 -0.985193 -0.984961 -0.985174
# 1824271            8103  0.999951 -0.985191 -0.985211 -0.984980 -0.985174
# 1824272            8103  1.000000 -0.985246 -0.985066 -0.984849 -0.984936
#
#            Volume    Target  EarningsPerShare  TotalAssets  ...  Close_lag_1  \
# ...

# %%
# Split df into train/test
column_indices = {name: i for i, name in enumerate(one_stock.columns)}

n = len(one_stock)
train_df = one_stock[0:int(n*0.9)]
test_df = one_stock[int(n*0.9):]

num_features = one_stock.shape[1]

print('Training Shape:', train_df.shape)
print('Test Shape:', test_df.shape)
# Out:
# Training Shape: (1081, 26)
# Test Shape: (121, 26)

# %%
# create Train X and y df's
X_train = train_df.drop('Target', axis=1)
y_train = train_df['Target']

# create Test X and y df's
X_test = test_df.drop('Target', axis=1)
y_test = test_df['Target']

# %%
X_test
# Out:
#          SecuritiesCode      Date      Open      High       Low     Close  \
# 1824152            8103  0.971094 -0.991541 -0.991601 -0.991361 -0.991546
# 1824153            8103  0.971143 -0.991595 -0.991637 -0.991398 -0.991583
# 1824154            8103  0.971192 -0.991595 -0.991637 -0.991436 -0.991601
# 1824155            8103  0.971338 -0.991668 -0.991691 -0.991436 -0.991601
# 1824156            8103  0.971386 -0.991686 -0.991691 -0.991473 -0.991656
# ...                 ...       ...       ...       ...       ...       ...
# 1824268            8103  0.996399 -0.985173 -0.985012 -0.984849 -0.985137
# 1824269            8103  0.996448 -0.984991 -0.984957 -0.984980 -0.985302
# 1824270            8103  0.999903 -0.985301 -0.985193 -0.984961 -0.985174
# 1824271            8103  0.999951 -0.985191 -0.985211 -0.984980 -0.985174
# 1824272            8103  1.000000 -0.985246 -0.985066 -0.984849 -0.984936
#
#            Volume  EarningsPerShare  TotalAssets  ForecastProfit  ...  \
# ...

# %% [markdown]
# ### Train and Fit Model

# %%
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(random_state = 42)

# Train the model on training data
rf.fit(X_train, y_train);

# %% [markdown]
# ### Predictions & Mean Absolute Error

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(X_test)

# Calculate the absolute errors
errors = abs(predictions - y_test)

# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'of the Sharpe Ratio')
# Out:
# Mean Absolute Error: 0.02 of the Sharpe Ratio

# %% [markdown]
# ### RMSE

# %%
# evaluate forecasts
rmse = sqrt(mean_squared_error(y_test, predictions))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.065

# %% [markdown]
# ### Feature Importance

# %%
# Saving feature names
feature_list = list(X_test.columns)

# Get numerical feature importances
importances = list(rf.feature_importances_)

# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]

# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: ExPost_SR            Importance: 0.39
# Variable: Return_Lag_1         Importance: 0.07
# Variable: Daily_Spread         Importance: 0.06
# Variable: 1_Week_Spread        Importance: 0.06
# Variable: Volume               Importance: 0.05
# Variable: Volume_lag_1         Importance: 0.05
# Variable: Date                 Importance: 0.04
# Variable: Open                 Importance: 0.04
# Variable: Daily_Max_Min        Importance: 0.04
# Variable: 2_Day_Spread         Importance: 0.04
# Variable: 1_Day_Spread         Importance: 0.03
# Variable: High                 Importance: 0.02
# Variable: Low                  Importance: 0.02
# Variable: Close                Importance: 0.02
# Variable: Open_lag_1           Importance: 0.02
# Variable: Close_lag_1          Importance: 0.02
# Variable: Low_lag_1            Importance: 0.02
# Variable: High_lag_1           Importance: 0.01
# Variable: SecuritiesCode       Importance: 0.0
# Variable: EarningsPerShare     Importance: 0.0
# ...

# %% [markdown]
# ### Plot Predictions vs Actual

# %%
plot(X_test, predictions, y_test)

# %% [markdown]
# ### Summary:
# * The predictions are much improved after feature training is performed with groupby.

# %% [markdown]
# # Compare Models - Multiple Stocks

# %%
# Create list of all securities codes
all_stocks_list = df1['SecuritiesCode'].values.tolist()

# Select 5 random stocks
rand_stocks = random.choices(all_stocks_list, k=5)

# %%
rand_stocks = [7596, 4998, 5802, 9663, 4464]
rand_stocks
# Out:
# [7596, 4998, 5802, 9663, 4464]

# %% [markdown]
# ## Only Price Information

# %%
# Create df with rand_stock list
rand_df = prices.loc[prices['SecuritiesCode'].isin(rand_stocks)]

# Copy of rand_df to ensure it stays the same with all three models
mult_stocks = rand_df.copy()
mult_stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6010 entries, 1631656 to 1632857
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SecuritiesCode  6010 non-null   int64
#  1   Date            6010 non-null   float64
#  2   Open            6010 non-null   float64
#  3   High            6010 non-null   float64
#  4   Low             6010 non-null   float64
#  5   Close           6010 non-null   float64
#  6   Volume          6010 non-null   float64
#  7   Target          6010 non-null   float64
#  8   High_lag_1      6010 non-null   float64
#  9   Open_lag_1      6010 non-null   float64
#  10  Close_lag_1     6010 non-null   float64
#  11  Volume_lag_1    6010 non-null   float64
#  12  Low_lag_1       6010 non-null   float64
#  13  Daily_Spread    6010 non-null   float64
#  14  Daily_Max_Min   6010 non-null   float64
#  15  1_Day_Spread    6010 non-null   float64
# ...

# %% [markdown]
# ### Train, Test, Split

# %%
# Sort df by date
mult_stocks = mult_stocks.sort_values(by='Date')

# Split df into train/test
column_indices = {name: i for i, name in enumerate(mult_stocks.columns)}

n = len(mult_stocks)
train_df = mult_stocks[0:int(n*0.9)]
test_df = mult_stocks[int(n*0.9):]

num_features = mult_stocks.shape[1]

print('Training Shape:', train_df.shape)
print('Test Shape:', test_df.shape)
# Out:
# Training Shape: (5409, 20)
# Test Shape: (601, 20)

# %%
# create Train X and y df's
X_train = train_df.drop('Target', axis=1)
y_train = train_df['Target']

# create Test X and y df's
X_test = test_df.drop('Target', axis=1)
y_test = test_df['Target']

# %%
X_test
# Out:
#          SecuritiesCode      Date      Open      High       Low     Close  \
# 946929             4998  0.971094 -0.973876 -0.974006 -0.973523 -0.973780
# 1053426            5802  0.971143 -0.968400 -0.968503 -0.968056 -0.968704
# 946930             4998  0.971143 -0.973967 -0.973951 -0.973374 -0.973726
# 1632738            7596  0.971143 -0.964470 -0.964647 -0.963764 -0.964523
# 2227837            9663  0.971143 -0.854897 -0.854369 -0.852650 -0.853820
# ...                 ...       ...       ...       ...       ...       ...
# 2227956            9663  1.000000 -0.804504 -0.796624 -0.799472 -0.796852
# 751774             4464  1.000000 -0.977496 -0.976956 -0.976900 -0.976939
# 947049             4998  1.000000 -0.979806 -0.979563 -0.979270 -0.979587
# 1053545            5802  1.000000 -0.973139 -0.973028 -0.972861 -0.972794
# 1632857            7596  1.000000 -0.964234 -0.963850 -0.963298 -0.963555
#
#            Volume  High_lag_1  Open_lag_1  Close_lag_1  Volume_lag_1  \
# ...

# %% [markdown]
# ### Train and Fit Model

# %%
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(random_state = 42)

# Train the model on training data
rf.fit(X_train, y_train);

# %% [markdown]
# ### Predictions & Mean Absolute Error

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(X_test)

# Calculate the absolute errors
errors = abs(predictions - y_test)

# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'of the Sharpe Ratio')
# Out:
# Mean Absolute Error: 0.01 of the Sharpe Ratio

# %% [markdown]
# ### RMSE

# %%
# evaluate forecasts
rmse = sqrt(mean_squared_error(y_test, predictions))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.018

# %% [markdown]
# ### Feature Importance

# %%
# Saving feature names
feature_list = list(X_test.columns)

# Get numerical feature importances
importances = list(rf.feature_importances_)

# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]

# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: ExPost_SR            Importance: 0.28
# Variable: 2_Day_Spread         Importance: 0.08
# Variable: Volume               Importance: 0.07
# Variable: Volume_lag_1         Importance: 0.07
# Variable: 1_Week_Spread        Importance: 0.07
# Variable: Return_Lag_1         Importance: 0.07
# Variable: Daily_Spread         Importance: 0.06
# Variable: Daily_Max_Min        Importance: 0.05
# Variable: 1_Day_Spread         Importance: 0.05
# Variable: Date                 Importance: 0.04
# Variable: Open                 Importance: 0.02
# Variable: High                 Importance: 0.02
# Variable: Low                  Importance: 0.02
# Variable: Close                Importance: 0.02
# Variable: High_lag_1           Importance: 0.02
# Variable: Open_lag_1           Importance: 0.02
# Variable: Close_lag_1          Importance: 0.02
# Variable: Low_lag_1            Importance: 0.02
# Variable: SecuritiesCode       Importance: 0.0

# %% [markdown]
# ### Plot Predictions vs Actual
# * Plot for each stock

# %%
# Create df with date, preds, and target
date_df = X_test.Date
date_df = pd.DataFrame(date_df)
date_df['Preds'] = predictions
date_df['Target'] = y_test

# Add Securities Codes to df
sec_code_df = X_test['SecuritiesCode']
sec_code_df = pd.DataFrame(sec_code_df)
preds_df = pd.concat([date_df, sec_code_df], axis=1)

# Create list of Securities Codes
sec_list = preds_df.SecuritiesCode.unique().tolist()

# Plot predictions for each stock
for code in sec_list:
    dfg = preds_df.loc[preds_df['SecuritiesCode'] == code]
    dfg = dfg.reset_index(drop=True)
    dfg = dfg.drop('SecuritiesCode', axis=1)
    dfg = dfg.drop('Date', axis=1)
    
    sns.set(rc={'figure.figsize':(11.7,8.27)})

    sns.set_theme(style="white", palette='bright', font_scale=2)

    ax = sns.lineplot(data=dfg, 
                          palette="bright", 
                          markers=False, 
                          dashes=False).set(title='Sharpe Ratio Predictions for Stock '+str(code), 
                                            xlabel="Trading Days",
                                            ylabel= "Sharpe Ratio (norm.)"
                                            )
    sns.despine()

    plt.show()

# %% [markdown]
# ### Summary:
# * It seems like the model is reducing error by plotting near the mean of each stock's Sharpe Ratio.
# * Considering the mean is similar for each stock, it will be very difficult to differentiate between stocks with this modeling approach.

# %% [markdown]
# ## With Financials

# %% [markdown]
# ### Train, Test, Split

# %%
# Create df with rand_stock list
rand_df = fin_df.loc[fin_df['SecuritiesCode'].isin(rand_stocks)]

# Copy of rand_df to ensure it stays the same with all three models
mult_stocks = rand_df.copy()
mult_stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6012 entries, 1052443 to 1633018
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SecuritiesCode            6012 non-null   int64
#  1   Date                      6012 non-null   float64
#  2   Open                      6012 non-null   float64
#  3   High                      6012 non-null   float64
#  4   Low                       6012 non-null   float64
#  5   Close                     6012 non-null   float64
#  6   Volume                    6012 non-null   float64
#  7   Target                    6012 non-null   float64
#  8   EarningsPerShare          6012 non-null   float64
#  9   TotalAssets               6012 non-null   float64
#  10  ForecastProfit            6012 non-null   float64
#  11  ForecastEarningsPerShare  6012 non-null   float64
#  12  NetSales                  6012 non-null   float64
# ...

# %%
# Sort df by date
mult_stocks = mult_stocks.sort_values(by='Date')

# Split df into train/test
n = len(mult_stocks)
train_df = mult_stocks[0:int(n*0.9)]
test_df = mult_stocks[int(n*0.9):]

print('Training Shape:', train_df.shape)
print('Test Shape:', test_df.shape)
# Out:
# Training Shape: (5410, 26)
# Test Shape: (602, 26)

# %%
# create Train X and y df's
X_train = train_df.drop('Target', axis=1)
y_train = train_df['Target']

# create Test X and y df's
X_test = test_df.drop('Target', axis=1)
y_test = test_df['Target']

# %%
X_test
# Out:
#          SecuritiesCode      Date      Open      High       Low     Close  \
# 1053524            5802  0.971094 -0.968645 -0.968557 -0.968000 -0.968595
# 2228052            9663  0.971094 -0.853078 -0.853826 -0.851157 -0.854368
# 1632899            7596  0.971143 -0.964470 -0.964647 -0.963764 -0.964523
# 947021             4998  0.971143 -0.973967 -0.973951 -0.973374 -0.973726
# 2228053            9663  0.971143 -0.854897 -0.854369 -0.852650 -0.853820
# ...                 ...       ...       ...       ...       ...       ...
# 947140             4998  1.000000 -0.979806 -0.979563 -0.979270 -0.979587
# 2228172            9663  1.000000 -0.804504 -0.796624 -0.799472 -0.796852
# 1053644            5802  1.000000 -0.973139 -0.973028 -0.972861 -0.972794
# 751853             4464  1.000000 -0.977496 -0.976956 -0.976900 -0.976939
# 1633018            7596  1.000000 -0.964234 -0.963850 -0.963298 -0.963555
#
#            Volume  EarningsPerShare  TotalAssets  ForecastProfit  ...  \
# ...

# %% [markdown]
# ### Train and Fit Model

# %%
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(random_state = 42)

# Train the model on training data
rf.fit(X_train, y_train);

# %% [markdown]
# ### Predictions & Mean Absolute Error

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(X_test)

# Calculate the absolute errors
errors = abs(predictions - y_test)

# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'of the Sharpe Ratio')
# Out:
# Mean Absolute Error: 0.01 of the Sharpe Ratio

# %% [markdown]
# ### RMSE

# %%
# evaluate forecasts
rmse = sqrt(mean_squared_error(y_test, predictions))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.019

# %% [markdown]
# ### Feature Importance

# %%
# Saving feature names
feature_list = list(X_test.columns)

# Get numerical feature importances
importances = list(rf.feature_importances_)

# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]

# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: ExPost_SR            Importance: 0.28
# Variable: 2_Day_Spread         Importance: 0.08
# Variable: Volume               Importance: 0.07
# Variable: Volume_lag_1         Importance: 0.07
# Variable: 1_Week_Spread        Importance: 0.07
# Variable: Return_Lag_1         Importance: 0.07
# Variable: Daily_Spread         Importance: 0.06
# Variable: Daily_Max_Min        Importance: 0.06
# Variable: 1_Day_Spread         Importance: 0.05
# Variable: Date                 Importance: 0.04
# Variable: Open                 Importance: 0.02
# Variable: High                 Importance: 0.02
# Variable: Low                  Importance: 0.02
# Variable: Close                Importance: 0.02
# Variable: High_lag_1           Importance: 0.02
# Variable: Open_lag_1           Importance: 0.02
# Variable: Close_lag_1          Importance: 0.02
# Variable: Low_lag_1            Importance: 0.02
# Variable: SecuritiesCode       Importance: 0.0
# Variable: EarningsPerShare     Importance: 0.0
# ...

# %% [markdown]
# ### Plot Predictions vs Actual
# * Plot for each stock

# %%
# Create df with date, preds, and target
date_df = X_test.Date
date_df = pd.DataFrame(date_df)
date_df['Preds'] = predictions
date_df['Target'] = y_test

# Add Securities Codes to df
sec_code_df = X_test['SecuritiesCode']
sec_code_df = pd.DataFrame(sec_code_df)
preds_df = pd.concat([date_df, sec_code_df], axis=1)

# Create list of Securities Codes
sec_list = preds_df.SecuritiesCode.unique().tolist()

# Plot predictions for each stock
for code in sec_list:
    dfg = preds_df.loc[preds_df['SecuritiesCode'] == code]
    dfg = dfg.reset_index(drop=True)
    dfg = dfg.drop('SecuritiesCode', axis=1)
    dfg = dfg.drop('Date', axis=1)
    
    # evaluate forecasts
    rmse = sqrt(mean_squared_error(y_test, predictions))
    print('Test RMSE: %.3f' % rmse)
    
    sns.set(rc={'figure.figsize':(11.7,8.27)})

    sns.set_theme(style="white", palette='bright', font_scale=2)

    ax = sns.lineplot(data=dfg, 
                          palette="bright", 
                          markers=False, 
                          dashes=False).set(title='Sharpe Ratio Predictions for Stock '+str(code), 
                                            xlabel="Trading Days",
                                            ylabel= "Sharpe Ratio (norm.)"
                                            )
    sns.despine()

    x = plt.show()
# Out:
# Test RMSE: 0.019
# Test RMSE: 0.019
# Test RMSE: 0.019
# Test RMSE: 0.019
# Test RMSE: 0.019

# %%
# Saving feature names
feature_list = list(X_test.columns)

# Get numerical feature importances
importances = list(rf.feature_importances_)

# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]

# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: ExPost_SR            Importance: 0.28
# Variable: 2_Day_Spread         Importance: 0.08
# Variable: Volume               Importance: 0.07
# Variable: Volume_lag_1         Importance: 0.07
# Variable: 1_Week_Spread        Importance: 0.07
# Variable: Return_Lag_1         Importance: 0.07
# Variable: Daily_Spread         Importance: 0.06
# Variable: Daily_Max_Min        Importance: 0.06
# Variable: 1_Day_Spread         Importance: 0.05
# Variable: Date                 Importance: 0.04
# Variable: Open                 Importance: 0.02
# Variable: High                 Importance: 0.02
# Variable: Low                  Importance: 0.02
# Variable: Close                Importance: 0.02
# Variable: High_lag_1           Importance: 0.02
# Variable: Open_lag_1           Importance: 0.02
# Variable: Close_lag_1          Importance: 0.02
# Variable: Low_lag_1            Importance: 0.02
# Variable: SecuritiesCode       Importance: 0.0
# Variable: EarningsPerShare     Importance: 0.0
# ...

# %% [markdown]
# ### Summary:
# * When modelled individually, the predictions follow the target much more closely.
# * The magnitude of the predictions is much closer to the actual target values when stocks are modeled individually, which will be very important for differentiation.

# %% [markdown]
# ## With Financials and Stock List

# %% [markdown]
# ### Train, Test, Split

# %%
# Merge Stock List with mult_stocks_merge
mult_stock_list = stock_list_df.loc[stock_list_df['SecuritiesCode'].isin(rand_stocks)]

mult_stock_list
# Out:
#          SecuritiesCode  Date      Open      High       Low     Close  \
# 1052443            5802  -1.0 -0.969537 -0.968901 -0.968756 -0.968677
# 945939             4998  -1.0 -0.987029 -0.987111 -0.986827 -0.987054
# 750652             4464  -1.0 -0.985592 -0.985681 -0.985278 -0.985594
# 2226971            9663  -1.0 -0.917297 -0.916912 -0.916464 -0.916813
# 1631815            7596  -1.0 -0.977278 -0.977083 -0.976751 -0.977103
# ...                 ...   ...       ...       ...       ...       ...
# 1053644            5802   1.0 -0.973139 -0.973028 -0.972861 -0.972794
# 751853             4464   1.0 -0.977496 -0.976956 -0.976900 -0.976939
# 947140             4998   1.0 -0.979806 -0.979563 -0.979270 -0.979587
# 2228172            9663   1.0 -0.804504 -0.796624 -0.799472 -0.796852
# 1633018            7596   1.0 -0.964234 -0.963850 -0.963298 -0.963555
#
#            Volume    Target  EarningsPerShare  TotalAssets  ...  Close_lag_1  \
# ...

# %%
# Split df into train/test
column_indices = {name: i for i, name in enumerate(mult_stock_list.columns)}

n = len(mult_stock_list)
train_df = mult_stock_list[0:int(n*0.9)]
test_df = mult_stock_list[int(n*0.9):]

print('Training Shape:', train_df.shape)
print('Test Shape:', test_df.shape)
# Out:
# Training Shape: (5410, 29)
# Test Shape: (602, 29)

# %%
# create Train X and y df's
X_train = train_df.drop('Target', axis=1)
y_train = train_df['Target']

# create Test X and y df's
X_test = test_df.drop('Target', axis=1)
y_test = test_df['Target']

# %%
X_test
# Out:
#          SecuritiesCode      Date      Open      High       Low     Close  \
# 751733             4464  0.971094 -0.974531 -0.974675 -0.974754 -0.974785
# 1632898            7596  0.971094 -0.964379 -0.964574 -0.963634 -0.964340
# 1632899            7596  0.971143 -0.964470 -0.964647 -0.963764 -0.964523
# 947021             4998  0.971143 -0.973967 -0.973951 -0.973374 -0.973726
# 2228053            9663  0.971143 -0.854897 -0.854369 -0.852650 -0.853820
# ...                 ...       ...       ...       ...       ...       ...
# 1053644            5802  1.000000 -0.973139 -0.973028 -0.972861 -0.972794
# 751853             4464  1.000000 -0.977496 -0.976956 -0.976900 -0.976939
# 947140             4998  1.000000 -0.979806 -0.979563 -0.979270 -0.979587
# 2228172            9663  1.000000 -0.804504 -0.796624 -0.799472 -0.796852
# 1633018            7596  1.000000 -0.964234 -0.963850 -0.963298 -0.963555
#
#            Volume  EarningsPerShare  TotalAssets  ForecastProfit  ...  \
# ...

# %% [markdown]
# ### Train and Fit Model

# %%
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(random_state = 42)

# Train the model on training data
rf.fit(X_train, y_train);

# %% [markdown]
# ### Predictions & Mean Absolute Error

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(X_test)

# Calculate the absolute errors
errors = abs(predictions - y_test)

# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'of the Sharpe Ratio')
# Out:
# Mean Absolute Error: 0.01 of the Sharpe Ratio

# %% [markdown]
# ### RMSE

# %%
# evaluate forecasts
rmse = sqrt(mean_squared_error(y_test, predictions))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.019

# %% [markdown]
# ### Feature Importance

# %%
# Saving feature names
feature_list = list(X_test.columns)

# Get numerical feature importances
importances = list(rf.feature_importances_)

# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]

# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: ExPost_SR            Importance: 0.28
# Variable: Volume               Importance: 0.07
# Variable: Volume_lag_1         Importance: 0.07
# Variable: 2_Day_Spread         Importance: 0.07
# Variable: 1_Week_Spread        Importance: 0.07
# Variable: Return_Lag_1         Importance: 0.07
# Variable: Daily_Spread         Importance: 0.06
# Variable: Daily_Max_Min        Importance: 0.06
# Variable: 1_Day_Spread         Importance: 0.05
# Variable: Date                 Importance: 0.04
# Variable: Open                 Importance: 0.02
# Variable: High                 Importance: 0.02
# Variable: Low                  Importance: 0.02
# Variable: Close                Importance: 0.02
# Variable: High_lag_1           Importance: 0.02
# Variable: Open_lag_1           Importance: 0.02
# Variable: Low_lag_1            Importance: 0.02
# Variable: Close_lag_1          Importance: 0.01
# Variable: SecuritiesCode       Importance: 0.0
# Variable: EarningsPerShare     Importance: 0.0
# ...

# %% [markdown]
# ### Plot Predictions vs Actual
# * Plot for each stock

# %%
# Create RMSE List
RMSE_stocklist = {}

# Create df with date, preds, and target
date_df = X_test.Date
date_df = pd.DataFrame(date_df)
date_df['Preds'] = predictions
date_df['Target'] = y_test

# Add Securities Codes to df
sec_code_df = X_test['SecuritiesCode']
sec_code_df = pd.DataFrame(sec_code_df)
preds_df = pd.concat([date_df, sec_code_df], axis=1)

# Create list of Securities Codes
sec_list = preds_df.SecuritiesCode.unique().tolist()

# Plot predictions for each stock
for code in sec_list:
    dfg = preds_df.loc[preds_df['SecuritiesCode'] == code]
    dfg = dfg.reset_index(drop=True)
    dfg = dfg.drop('SecuritiesCode', axis=1)
    dfg = dfg.drop('Date', axis=1)
    
    # evaluate forecasts
    rmse = sqrt(mean_squared_error(dfg['Target'].values, dfg['Preds'].values))
    RMSE_stocklist[code] = [rmse]
    print('Test RMSE: %.3f' % rmse)
    
    sns.set(rc={'figure.figsize':(11.7,8.27)})

    sns.set_theme(style="white", palette='bright', font_scale=2)

    ax = sns.lineplot(data=dfg, 
                          palette="bright", 
                          markers=False, 
                          dashes=False).set(title='Sharpe Ratio Predictions for Stock '+str(code), 
                                            xlabel="Trading Days",
                                            ylabel= "Sharpe Ratio (norm.)"
                                            )
    sns.despine()

    x = plt.show()
# Out:
# Test RMSE: 0.017
# Test RMSE: 0.028
# Test RMSE: 0.014
# Test RMSE: 0.011
# Test RMSE: 0.020

# %%
RMSE_stocklist
# Out:
# {5802: [0.016818677154557135],
#  9663: [0.02777069541035779],
#  7596: [0.014053129516546947],
#  4998: [0.010711852164485041],
#  4464: [0.020080766473888734]}

# %% [markdown]
# ### Summary:
# * There is little change between adding stock list information from the financial information.
#     * The RMSE and the feature importances have the same values.

# %% [markdown]
# ## Individual Models, Multiple Stocks

# %% [markdown]
# ### Model and Plot
# * Same stocks as above models with multiple stocks

# %%
# Create RMSE List
RMSE_mult_stocks = {}

# Create Preds df
preds_df = pd.DataFrame()

# Run Model and Plot for all 5 stocks
for code in rand_stocks:
    dfg = mult_stocks.loc[mult_stocks['SecuritiesCode'] == code]
    
    # Train, Test, Split
    n = len(dfg)
    train_df = dfg[0:int(n*0.9)]
    test_df = dfg[int(n*0.9):]
    
        # create Train X and y df's
    X_train = train_df.drop('Target', axis=1)
    y_train = train_df['Target']

        # create Test X and y df's
    X_test = test_df.drop('Target', axis=1)
    y_test = test_df['Target']
    
    # Instantiate and Fit Model
    rf = RandomForestRegressor(random_state = 42)

    # Train the model on training data
    rf.fit(X_train, y_train);
    
    # df of preds by sec code
    predictions = rf.predict(X_test)
    predies_df = pd.DataFrame(data=predictions, columns=[code])
    
    # date and preds in same df
    date_df = X_test.Date
    date_df = pd.DataFrame(date_df)
    date_df = date_df.reset_index(drop=True)
    plot_df = pd.concat([date_df, predies_df], axis=1)

    target_df = pd.DataFrame(data=y_test)
    target_df = target_df.reset_index(drop=True)
    target_df = pd.concat([plot_df, target_df], axis=1)
    
    # evaluate forecasts with RMSE
    rmse = sqrt(mean_squared_error(y_test, predictions))
    
    # Store and print RMSE
    RMSE_mult_stocks[code] = [rmse]
    print('Test RMSE: %.3f' % rmse)
    
    # Drop Date column
    target_df = target_df.drop('Date', axis=1)
    
    sns.set(rc={'figure.figsize':(11.7,8.27)})

    sns.set_theme(style="white", palette='bright', font_scale=2)

    ax = sns.lineplot(data=target_df, 
                          palette="bright", 
                          markers=False, 
                          dashes=False).set(title='Sharpe Ratio Predictions for Stock '+str(code), 
                                            xlabel="Trading Days",
                                            ylabel= "Sharpe Ratio (norm.)"
                                            )
    sns.despine()

    x = plt.show()
# Out:
# Test RMSE: 0.014
# Test RMSE: 0.011
# Test RMSE: 0.017
# Test RMSE: 0.023
# Test RMSE: 0.021

# %%
RMSE_mult_stocks
# Out:
# {7596: [0.013868413742444819],
#  4998: [0.010895120350831254],
#  5802: [0.016993148151087198],
#  9663: [0.022916699095361207],
#  4464: [0.02082252442644021]}

# %% [markdown]
# ### Summary
# * While the RMSE has increased for some stocks compared to modelling all stocks together, the error for some stocks is considerably lower and the predictions seem to match more closely with the target from a visual inspection.
#     * The improvements are especially true for stock 9663, which

# %% [markdown]
# ## Compare Single Model to Individual Models

# %%
RMSE_mult_df = pd.DataFrame(RMSE_mult_stocks)
RMSE_stocklist_df = pd.DataFrame(RMSE_stocklist)
#RMSE_mult_df = RMSE_mult_df.append(RMSE_stocklist_df)
#RMSE_mult_df = RMSE_mult_df.reset
#RMSE_mult_df

# %%
RMSE_mult_df = pd.DataFrame(RMSE_mult_df.unstack())
RMSE_mult_df = RMSE_mult_df.rename(columns={0: "RMSE"})
RMSE_mult_df = RMSE_mult_df.droplevel(level=1)
RMSE_mult_df['Model_Type'] = 'Individual_Models'
RMSE_mult_df = RMSE_mult_df.reset_index(drop=False)
RMSE_mult_df = RMSE_mult_df.rename(columns={"index": "Securities_Code"})
RMSE_mult_df
# Out:
#    Securities_Code      RMSE         Model_Type
# 0             7596  0.013868  Individual_Models
# 1             4998  0.010895  Individual_Models
# 2             5802  0.016993  Individual_Models
# 3             9663  0.022917  Individual_Models
# 4             4464  0.020823  Individual_Models

# %%
RMSE_stocklist_df = pd.DataFrame(RMSE_stocklist_df.unstack())
RMSE_stocklist_df = RMSE_stocklist_df.rename(columns={0: "RMSE"})
RMSE_stocklist_df = RMSE_stocklist_df.droplevel(level=1)
RMSE_stocklist_df['Model_Type'] = 'Single_Model'
RMSE_stocklist_df = RMSE_stocklist_df.reset_index(drop=False)
RMSE_stocklist_df = RMSE_stocklist_df.rename(columns={"index": "Securities_Code"})
RMSE_stocklist_df
# Out:
#    Securities_Code      RMSE    Model_Type
# 0             5802  0.016819  Single_Model
# 1             9663  0.027771  Single_Model
# 2             7596  0.014053  Single_Model
# 3             4998  0.010712  Single_Model
# 4             4464  0.020081  Single_Model

# %%
combined = RMSE_mult_df.append(RMSE_stocklist_df)
combined
# Out:
#    Securities_Code      RMSE         Model_Type
# 0             7596  0.013868  Individual_Models
# 1             4998  0.010895  Individual_Models
# 2             5802  0.016993  Individual_Models
# 3             9663  0.022917  Individual_Models
# 4             4464  0.020823  Individual_Models
# 0             5802  0.016819       Single_Model
# 1             9663  0.027771       Single_Model
# 2             7596  0.014053       Single_Model
# 3             4998  0.010712       Single_Model
# 4             4464  0.020081       Single_Model

# %%
sns.set(rc={'figure.figsize':(15.7,12.27)})
sns.set_theme(style="white", palette='bright', font_scale=1)
sns.catplot(x='Securities_Code', y='RMSE', data=combined, hue='Model_Type', jitter=False)

# %% [markdown]
# # GridSearch Hyper-Parameters
# * Dropped as it is computationally expensive and did not improve model scores.

# %%
#model = RandomForestRegressor()
#grid_rf = {
#'n_estimators': [20, 50, 100, 500, 1000],  
#'max_depth': np.arange(1, 15, 1),  
#'min_samples_split': [2, 10, 9], 
#'min_samples_leaf': np.arange(1, 15, 2, dtype=int),  
#'bootstrap': [True, False], 
#'random_state': [1, 2, 30, 42]
#}
#rscv = RandomizedSearchCV(estimator=model,param_distributions=grid_rf, cv=3, n_jobs=-1, verbose=2, n_iter=2)
#rscv_fit = rscv.fit(X_train, y_train)
#best_parameters = rscv_fit.best_params_
#print(best_parameters)

# %% [markdown]
# # One Model Submission

# %% [markdown]
# ## Create small df for practice

# %%
df2 = stock_list_df.copy()
df2
# Out:
#          SecuritiesCode  Date      Open      High       Low     Close  \
# 0                  1301  -1.0 -0.950517 -0.950401 -0.949304 -0.950190
# 2284676            9843  -1.0 -0.756476 -0.756075 -0.751518 -0.755952
# 599902             3926  -1.0 -0.943494 -0.943703 -0.943799 -0.944657
# 1340402            6644  -1.0 -0.978151 -0.978078 -0.977796 -0.977980
# 1341604            6645  -1.0 -0.917661 -0.916278 -0.915531 -0.915809
# ...                 ...   ...       ...       ...       ...       ...
# 403501             3153   1.0 -0.983663 -0.983473 -0.983226 -0.983330
# 1673024            7732   1.0 -0.968964 -0.968557 -0.968354 -0.968613
# 404703             3154   1.0 -0.983936 -0.983581 -0.983505 -0.983476
# 1670620            7730   1.0 -0.971165 -0.970421 -0.970631 -0.970238
# 2332760            9997   1.0 -0.987702 -0.987401 -0.987443 -0.987547
#
#            Volume    Target  EarningsPerShare  TotalAssets  ...  Close_lag_1  \
# ...

# %%
#df2['DateValue']=df2['Date'].str.replace('-','')
small_prices = df2[df2['Date']>0.8]
#small_prices = small_prices[small_prices['DateValue']<'20211202']
#small_prices=small_prices.drop(['DateValue'],axis=1)
small_prices
# Out:
#          SecuritiesCode      Date      Open      High       Low     Close  \
# 866780             4733  0.946519 -0.871089 -0.871204 -0.870003 -0.870618
# 168384             2211  0.946519 -0.957503 -0.957442 -0.957719 -0.958625
# 345111             2914  0.946519 -0.962233 -0.962330 -0.961992 -0.962788
# 1929831            8367  0.946519 -0.968509 -0.968521 -0.968466 -0.969015
# 272978             2664  0.946519 -0.946769 -0.946979 -0.945982 -0.946538
# ...                 ...       ...       ...       ...       ...       ...
# 403501             3153  1.000000 -0.983663 -0.983473 -0.983226 -0.983330
# 1673024            7732  1.000000 -0.968964 -0.968557 -0.968354 -0.968613
# 404703             3154  1.000000 -0.983936 -0.983581 -0.983505 -0.983476
# 1670620            7730  1.000000 -0.971165 -0.970421 -0.970631 -0.970238
# 2332760            9997  1.000000 -0.987702 -0.987401 -0.987443 -0.987547
#
#            Volume    Target  EarningsPerShare  TotalAssets  ...  Close_lag_1  \
# ...

# %% [markdown]
# ## Train & Test

# %% [markdown]
# ### Train, Test, Split

# %%
# Cut out last date as df_test
df_test = small_prices.loc[small_prices['Date'] == 1.0]
final_model = small_prices.loc[small_prices['Date'] != 1.0]

#final_model
df_test
# Out:
#          SecuritiesCode  Date      Open      High       Low     Close  \
# 921897             4934   1.0 -0.824698 -0.814907 -0.820183 -0.814198
# 874217             4755   1.0 -0.979170 -0.979273 -0.978971 -0.979313
# 914729             4919   1.0 -0.899105 -0.897452 -0.897058 -0.896728
# 1345209            6652   1.0 -0.951190 -0.951052 -0.951169 -0.951340
# 880227             4771   1.0 -0.967035 -0.964647 -0.966171 -0.964322
# ...                 ...   ...       ...       ...       ...       ...
# 403501             3153   1.0 -0.983663 -0.983473 -0.983226 -0.983330
# 1673024            7732   1.0 -0.968964 -0.968557 -0.968354 -0.968613
# 404703             3154   1.0 -0.983936 -0.983581 -0.983505 -0.983476
# 1670620            7730   1.0 -0.971165 -0.970421 -0.970631 -0.970238
# 2332760            9997   1.0 -0.987702 -0.987401 -0.987443 -0.987547
#
#            Volume    Target  EarningsPerShare  TotalAssets  ...  Close_lag_1  \
# ...

# %%
# Split df into train/test
column_indices = {name: i for i, name in enumerate(final_model.columns)}

n = len(final_model)
train_df = final_model[0:int(n*0.9)]
test_df = final_model[int(n*0.9):]

num_features = final_model.shape[1]

print('Training Shape:', train_df.shape)
print('Test Shape:', test_df.shape)
# Out:
# Training Shape: (405034, 29)
# Test Shape: (45004, 29)

# %%
# create Train X and y df's
X_train = train_df.drop('Target', axis=1)
y_train = train_df['Target']

# create Test X and y df's
X_test = test_df.drop('Target', axis=1)
y_test = test_df['Target']

# %%
X_test
# Out:
#          SecuritiesCode      Date      Open      High       Low     Close  \
# 2100489            9076  0.991533 -0.975240 -0.975345 -0.975165 -0.975113
# 71746              1884  0.991533 -0.850895 -0.850930 -0.847426 -0.849985
# 1872337            8218  0.991533 -0.952918 -0.952537 -0.952326 -0.952235
# 1492539            7060  0.991533 -0.973203 -0.973354 -0.973075 -0.973616
# 432329             3231  0.991533 -0.948370 -0.948627 -0.950684 -0.949697
# ...                 ...       ...       ...       ...       ...       ...
# 1926449            8362  0.999951 -0.975786 -0.975653 -0.975277 -0.975825
# 1910823            8337  0.999951 -0.995816 -0.995782 -0.995690 -0.995782
# 168608             2211  0.999951 -0.959722 -0.959216 -0.958670 -0.959191
# 783496             4547  0.999951 -0.960231 -0.959723 -0.959529 -0.960360
# 1009216            5401  0.999951 -0.969328 -0.968783 -0.968672 -0.968613
#
#            Volume  EarningsPerShare  TotalAssets  ForecastProfit  ...  \
# ...

# %% [markdown]
# ## Train Model

# %%
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(random_state = 42)

# Train the model on training data
rf.fit(X_train, y_train);

# %% [markdown]
# ## Predictions & Mean Absolute Error

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(X_test)

# Calculate the absolute errors
errors = abs(predictions - y_test)

# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'of the Sharpe Ratio')

# %% [markdown]
# ## RMSE

# %%
# evaluate forecasts
rmse = sqrt(mean_squared_error(y_test, predictions))
print('Test RMSE: %.3f' % rmse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1315/2620329101.py in <module>
#       1 # evaluate forecasts
# ----> 2 rmse = sqrt(mean_squared_error(y_test, predictions))
#       3 print('Test RMSE: %.3f' % rmse)
#
# NameError: name 'sqrt' is not defined

# %% [markdown]
# ## Feature Importance

# %%
# Saving feature names
feature_list = list(X_test.columns)

# Get numerical feature importances
importances = list(rf.feature_importances_)

# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]

# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];

# %% [markdown]
# ## Check Submission Score

# %%
test_only = df_test.drop('Target', axis=1) 
y_pred = rf.predict(test_only)
sp_copy['Target'] = y_pred
sp_copy = sp_copy.sort_values(by = ['Target'], ascending = False)
sp_copy['Rank'] = np.arange(len(sp_copy.index))
#sp_copy = sp_copy.sort_values(by = "SecuritiesCode", ascending = True)
sp_copy = sp_copy.drop(["Target"], axis = 1)
#submission = sp_copy[["Date", "SecuritiesCode", "Rank"]] 
result = pd.merge(test_set_target, sp_copy, on="SecuritiesCode")
result = result.sort_values(by = ['Rank'], ascending = True)
result
# Out:
#               RowId      Date_x  SecuritiesCode    Open    High     Low  \
# 461   20211203_3708  2021-12-03            3708  4135.0  4170.0  4085.0
# 1367  20211203_7419  2021-12-03            7419  2270.0  2288.0  2258.0
# 184   20211203_2393  2021-12-03            2393  1425.0  1425.0  1409.0
# 1801  20211203_9072  2021-12-03            9072  2062.0  2071.0  2028.0
# 1716  20211203_8706  2021-12-03            8706   735.0   757.0   735.0
# ...             ...         ...             ...     ...     ...     ...
# 347   20211203_3178  2021-12-03            3178  1215.0  1251.0  1215.0
# 1629  20211203_8279  2021-12-03            8279  6750.0  6890.0  6710.0
# 485   20211203_3854  2021-12-03            3854  1538.0  1590.0  1513.0
# 563   20211203_4113  2021-12-03            4113  1450.0  1479.0  1446.0
# 1649  20211203_8344  2021-12-03            8344   814.0   834.0   814.0
#
#        Close  Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag  \
# ...

# %% [markdown]
# ## Scoring Function

# %%
def _calc_spread_return_per_day(df, portfolio_size, toprank_weight_ratio):
        """
        Args:
            df (pd.DataFrame): predicted results
            portfolio_size (int): # of equities to buy/sell
            toprank_weight_ratio (float): the relative weight of the most highly ranked stock compared to the least.
        Returns:
            (float): spread return
        """
        assert df['Rank'].min() == 0
        assert df['Rank'].max() == len(df['Rank']) - 1
        weights = np.linspace(start=toprank_weight_ratio, stop=1, num=portfolio_size)
        purchase = (df.sort_values(by='Rank')['Target'][:portfolio_size] * weights).sum() / weights.mean()
        short = (df.sort_values(by='Rank', ascending=False)['Target'][:portfolio_size] * weights).sum() / weights.mean()
        return purchase - short

# %%
z = _calc_spread_return_per_day(result, 200, 2)
z
# Out:
# 0.3506710280696339

# %% [markdown]
# # Individual Models Prediction

# %%
df2 = stock_list_df.copy()
#small_prices = df2[df2['Date']>0.0]

# %%
df2
# Out:
#          SecuritiesCode  Date      Open      High       Low     Close  \
# 0                  1301  -1.0 -0.950517 -0.950401 -0.949304 -0.950190
# 2284676            9843  -1.0 -0.756476 -0.756075 -0.751518 -0.755952
# 599902             3926  -1.0 -0.943494 -0.943703 -0.943799 -0.944657
# 1340402            6644  -1.0 -0.978151 -0.978078 -0.977796 -0.977980
# 1341604            6645  -1.0 -0.917661 -0.916278 -0.915531 -0.915809
# ...                 ...   ...       ...       ...       ...       ...
# 403501             3153   1.0 -0.983663 -0.983473 -0.983226 -0.983330
# 1673024            7732   1.0 -0.968964 -0.968557 -0.968354 -0.968613
# 404703             3154   1.0 -0.983936 -0.983581 -0.983505 -0.983476
# 1670620            7730   1.0 -0.971165 -0.970421 -0.970631 -0.970238
# 2332760            9997   1.0 -0.987702 -0.987401 -0.987443 -0.987547
#
#            Volume    Target  EarningsPerShare  TotalAssets  ...  Close_lag_1  \
# ...

# %%
# Cut out last date as df_test
df_test = stock_list_df.loc[stock_list_df['Date'] == 1.0]
multi_model = stock_list_df.loc[stock_list_df['Date'] != 1.0]

#multi_model
df_test
# Out:
#          SecuritiesCode  Date      Open      High       Low     Close  \
# 921897             4934   1.0 -0.824698 -0.814907 -0.820183 -0.814198
# 874217             4755   1.0 -0.979170 -0.979273 -0.978971 -0.979313
# 914729             4919   1.0 -0.899105 -0.897452 -0.897058 -0.896728
# 1345209            6652   1.0 -0.951190 -0.951052 -0.951169 -0.951340
# 880227             4771   1.0 -0.967035 -0.964647 -0.966171 -0.964322
# ...                 ...   ...       ...       ...       ...       ...
# 403501             3153   1.0 -0.983663 -0.983473 -0.983226 -0.983330
# 1673024            7732   1.0 -0.968964 -0.968557 -0.968354 -0.968613
# 404703             3154   1.0 -0.983936 -0.983581 -0.983505 -0.983476
# 1670620            7730   1.0 -0.971165 -0.970421 -0.970631 -0.970238
# 2332760            9997   1.0 -0.987702 -0.987401 -0.987443 -0.987547
#
#            Volume    Target  EarningsPerShare  TotalAssets  ...  Close_lag_1  \
# ...

# %%
test_set_targets = df_test[['Target', 'SecuritiesCode']]
test_set_targets
# Out:
#            Target  SecuritiesCode
# 921897  -0.308077            4934
# 874217  -0.293048            4755
# 914729  -0.276443            4919
# 1345209 -0.286010            6652
# 880227  -0.269903            4771
# ...           ...             ...
# 403501  -0.277301            3153
# 1673024 -0.284100            7732
# 404703  -0.291901            3154
# 1670620 -0.287626            7730
# 2332760 -0.296895            9997
#
# [2000 rows x 2 columns]

# %%
new_col_list = multi_model.SecuritiesCode.unique().tolist()
new_col_list_small = new_col_list[:5]

preds_df = pd.DataFrame()

for code in new_col_list:
    dfg = multi_model.loc[multi_model['SecuritiesCode'] == code]
    
    # Train, Test, Split
    train_df = dfg
    test_df = df_test.loc[df_test['SecuritiesCode'] == code]
    
        # create Train X and y df's
    X_train = train_df.drop('Target', axis=1)
    y_train = train_df['Target']

        # create Test X and y df's
    X_test = test_df.drop('Target', axis=1)
    y_test = test_df['Target']
    
    # Instantiate and Fit Model
    rf = RandomForestRegressor(random_state = 42)

    # Train the model on training data
    rf.fit(X_train, y_train);
    
    # df of preds by sec code
    predictions = rf.predict(X_test)
    predies_df = pd.DataFrame(data=predictions, columns=[code])
    
    # concat df to preds_df
    preds_df = pd.concat([preds_df, predies_df], axis=1)
    
preds_df

# %%
preds_df
# Out:
#        1301      9843     3926     6644      6645      3925      6651  \
# 0 -0.305946 -0.304332 -0.26826 -0.28919 -0.306683 -0.299442 -0.287824
#
#        1723     3923      6652  ...      4934      7944      6612      7092  \
# 0 -0.319428 -0.26198 -0.317871  ... -0.230943 -0.311631 -0.246338 -0.281873
#
#        4165      4167      7358      4168      7342      4169
# 0 -0.331447 -0.282028 -0.306583 -0.292548 -0.261766 -0.363898
#
# [1 rows x 2000 columns]

# %% [markdown]
# ## Predictions df

# %%
# Pull predictions from preds_df and arrange them for scoring
pred_practice = preds_df.loc[0]
d = {'Target': pred_practice}
pred_practice_df = pd.DataFrame(d)
pred_practice_df = pred_practice_df.rename_axis('SecuritiesCode').reset_index()

# Generate df with actual ranks and predicted ranks
#test_set_targets = test_set_target.sort_values(by = ['Target'], ascending = False)
#test_set_targets['Actual_Rank'] = np.arange(len(pred_practice_df.index))

# Rank by Target values
pred_practice_df = pred_practice_df.sort_values(by = ['Target'], ascending = False)
pred_practice_df['Rank'] = np.arange(len(pred_practice_df.index))

# Drop Target column
pred_practice_df = pred_practice_df.drop(["Target"], axis = 1)

# Merge results with actual target values from original test set
result = pd.merge(test_set_targets, pred_practice_df, on="SecuritiesCode")
result = result.sort_values(by = ['Rank'], ascending = True)
result
# Out:
#         Target  SecuritiesCode  Rank
# 1421 -0.272776            7351     0
# 659  -0.273282            5698     1
# 1375 -0.261866            3558     2
# 21   -0.269290            4390     3
# 331  -0.187169            6182     4
# ...        ...             ...   ...
# 1544 -0.217627            6740  1995
# 1324 -0.318583            9441  1996
# 1224 -0.426703            2158  1997
# 242  -0.271395            6027  1998
# 630  -0.306975            4080  1999
#
# [2000 rows x 3 columns]

# %% [markdown]
# ## Check Submission Score

# %%
z = _calc_spread_return_per_day(result, 200, 2)
z
# Out:
# 3.049440757268002
